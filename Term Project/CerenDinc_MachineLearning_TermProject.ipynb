# %% [markdown]
# # 0. Initialize

# %% [markdown]
# ## 0.1. Import Libraries

# %%
# %matplotlib inline
# %load_ext autoreload
# %autoreload 2
import os, sys, glob
import gzip
import random
import tqdm
import json
import numpy as np
import pandas as pd
pd.set_option("display.max_columns", None)

from IPython import display
import matplotlib as mpl
from matplotlib import pyplot as plt

# %% [markdown]
# ## 0.2. DEFINE VARIABLES

# %%
from google.colab import drive
drive.mount("./drive")

DATA_PATH = './drive/My Drive/' # '<insert-your-training-data-path-here>'

ROUND = 2 # This project will have 3 rounds of predictions: 1,2,3
STUDENT_ID = '28220'#'<insert-your-id-here>'
PROJECT_CODE = 'xx'#'<insert-your-code-here>' # Same code for the annotation eg. CS412xxxxx
# Out:
# Mounted at ./drive

# %% [markdown]
# ## 0.3. Read Training & Evaluation Data

# %% [markdown]
# ### 0.3.1. Get the labels for tweets

# %%
#trainingTweetDf = pd.read_csv('{}training-tweet.csv'.format(DATA_PATH))
trainingTweetDf = pd.read_csv('{}training-tweet.csv'.format(DATA_PATH), dtype={'tweet_id': str, 'isPolitical': str})
trainingTweetDf
# Out:
#                  tweet_id isPolitical
# 0     1597170281545551872         Yes
# 1     1431700027471192069          No
# 2     1566035577090281472         Yes
# 3     1591538690869940225         Yes
# 4     1583898169238167554         Yes
# ...                   ...         ...
# 2995  1593539327623151619         Yes
# 2996  1393886554062524418          No
# 2997  1597925615092764672         Yes
# 2998  1585291418616176640         Yes
# 2999  1594775287622995971         Yes
#
# [3000 rows x 2 columns]

# %%
trainingTweetDf.isPolitical.value_counts()
# Out:
# Yes    2003
# No      997
# Name: isPolitical, dtype: int64

# %% [markdown]
# ### 0.3.2. Get the labels for users

# %%
trainingUserDf = pd.read_csv('{}training-user.csv'.format(DATA_PATH))
#trainingUserDf = pd.read_csv('training-user.csv')
trainingUserDf
# Out:
#           screen_name isBot
# 0       koftecancaddy    No
# 1              ahaber    No
# 2     selahat03949652    No
# 3       erdin06357062    No
# 4       bhct__necatii    No
# ...               ...   ...
# 2995     djblumenberg    No
# 2996           mel1sq    No
# 2997         eren_yz1   Yes
# 2998      ergnyildiz4    No
# 2999   isadal24978794   Yes
#
# [3000 rows x 2 columns]

# %%
trainingUserDf.isBot.value_counts()
# Out:
# No     2424
# Yes     576
# Name: isBot, dtype: int64

# %% [markdown]
# ### 0.3.3. Expand your dataset with metadata and tweets

# %%
# You can also expand training data by downloading your own labeled datasets following the link
# Download the documents under "Link to training data"

print('http://www.onurvarol.com/Annotation-CS412-202201/reports/report_{}.html'.format(PROJECT_CODE))
# Out:
# http://www.onurvarol.com/Annotation-CS412-202201/reports/report_CS412c38461f5453a.html

# %% [markdown]
# # 1. EXTRACT FEATURES
# Under *1.1. Political Tweet Detection* and *1.2. Bot Detection*, we firstly collect raw data for processing. We then combine some of them (total_interactions = num_favorites + num_retweets) or use them to extract features (whether the tweet has one of the political entities @meralaksener, @kilicdarogluk etc.).
#
# We expect you to collect more raw data from **tweet_metadata**, **user_profiles** and **user_tweets** files by creating a function as shown in below examples such as *check_if_retweet()* and using it while iterating over data as shown under *Merge Collected Features*.
#
# We also expect you to create new variables as much as you can from the data in order to make your predictions more accurate. For example, you may want to check:
#
# - The tweet sources that a user frequently uses
# - Whether the user is a verified account or not
#
# ...
#
# to assess whether **a user is a bot or not** and whether **a tweet is political or not**.

# %%
PATH_TO_DOWNLOADED = './drive/My Drive/' # 'D:/Users/suuser/Desktop/Sabancı/CS412/spring-2022/project/'

# %% [markdown]
# ## 1.1. Political Tweet Detection
# This part stands for the feature extraction of tweets. We start with collecting the raw data from *tweet_metadata*, then use some of them to extract features.

# %% [markdown]
# ### 1.1.1. Get Raw Data

# %% [markdown]
# #### 1.1.1.1. Check if Retweet

# %%
def check_if_retweet(tweet_metadata_line):
    is_retweet = 0
    retweeted_username = None

    try:
        tweet_metadata_line['retweeted_status']
        retweeted_username = tweet_metadata_line['retweeted_status']['user']['screen_name'].lower()
        is_retweet = 1

    except KeyError:
        pass

    return is_retweet, retweeted_username

# %% [markdown]
# #### 1.1.1.2. Get Tweet Text

# %%
def get_tweet_text(tweet_metadata_line):
    text = tweet_metadata_line['text']

    return text

# %% [markdown]
# #### 1.1.1.3. Get Tweet ID

# %%
def get_tweet_id(tweet_metadata_line):
    id_str = tweet_metadata_line['id_str']

    return id_str

# %% [markdown]
# #### 1.1.1.4. Get Number of Mentions and Hashtags

# %%
def get_number_mentions_hashtags(tweet_metadata_line):
    num_mentions = len(tweet_metadata_line['entities']['user_mentions'])
    num_hashtags = len(tweet_metadata_line['entities']['hashtags'])

    return num_mentions, num_hashtags

# %% [markdown]
# #### 1.1.1.5. Get Number of Retweets and Favorites

# %%
def get_number_retweets_favorites(tweet_metadata_line):
    retweet_count = tweet_metadata_line['retweet_count']
    favorite_count = tweet_metadata_line['favorite_count']

    return retweet_count, favorite_count

# %% [markdown]
# #### 1.1.1.6. Get User Info

# %%
def get_user_info(tweet_metadata_line):
    id = tweet_metadata_line['user']['id_str']
    screen_name = tweet_metadata_line['user']['screen_name'].lower()
    description = tweet_metadata_line['user']['description']
    is_verified = tweet_metadata_line['user']['verified']
    follower = tweet_metadata_line['user']['followers_count']
    following = tweet_metadata_line['user']['friends_count']
    tweet_num = tweet_metadata_line['user']['statuses_count']

    return id, screen_name, description, is_verified, follower, following, tweet_num

# %% [markdown]
# ### 1.1.2. Derive Manually Crafted Features

# %% [markdown]
# #### 1.1.2.1. Check for political entity in text

# %%
def check_political_ent(text):

    # the list below can be modified and some new names may be added (or removed)
    list_of_entities = ['meral_aksener', 'kilicdarogluk', 'vekilince', 'RTErdogan', 'MevlutCavusoglu', 'umitozdag',
                        'drfahrettinkoca', 'yenisafak', 'solcugazete', 'odatv', 'suleymansoylu', 'haskologlu',
                        'mansuryavas06', 'dbdevletbahceli',  'Ahmet_Davutoglu', 'alibabacan', 'gazetesozcu', 'ekrem_imamoglu']

    entities_in_text = [ent for ent in list_of_entities if ent.lower() in text.lower()]
    number_entities = len(entities_in_text)

    return number_entities

# %% [markdown]
# #### 1.1.2.2. Number of total interactions

# %%
def total_interactions(retweet_count, favorite_count):
    total_num_interactions = retweet_count + favorite_count

    return total_num_interactions

# %% [markdown]
# ### 1.1.2. Collect data using the functions above and transform into a Pandas DataFrame

# %%
dfPolitical = {'tweet_id':[],
              'is_retweet':[],
              'retweeted_username':[],
              'text':[],
              'num_mentions':[],
              'num_hashtags':[],
              'num_retweets':[],
              'num_favorites':[],
              'user_id':[],
              'user_screen_name':[],
              'user_description':[],
              'user_verified':[],
              'user_follower':[],
              'user_following':[],
              'user_num_of_tweets':[],
              'num_political_entities':[],
              'total_interactions':[],
              'check':[]}


with gzip.open(f"{PATH_TO_DOWNLOADED}tweet_metadata.jsons.gz", "rb") as f:
    for line in f:
        line = json.loads(line)

        # raw data:
        id_str = get_tweet_id(line)
        is_retweet, retweeted_username = check_if_retweet(line)
        text = get_tweet_text(line)
        num_mentions, num_hashtags = get_number_mentions_hashtags(line)
        retweet_count, favorite_count = get_number_retweets_favorites(line)
        user_id_str, screen_name, user_description, user_verified, user_follower, user_following, user_num_of_tweets = get_user_info(line)

        # manually crafted data:
        num_political_entities = check_political_ent(text)
        total_num_interactions = total_interactions(retweet_count, favorite_count)

        list_of_entities = ['akşener', 'aksener', 'gündem', 'kürt', 'adalet', 'hukuk', 'terör', 'işleri', 'bakan', 'pkk', 'ypg', 'kamu', 'amerika', 'parti', 'muhafaza', 'vergi',
                    'solcu', 'ülke', 'afgan', 'yunan', 'atatürk', 'erdoğan', 'erdogan', 'suriye', 'memleket', 'vatan', 'haber','akp', 'chp', 'mhp', 'hdp', 'zafer', 'kalkınma', 'iyi parti', 'türk', 'millet', 'devlet', 'kılıçdaroğlu', 'kilicdaroglu',
                    'muharrem ince', 'vekilince', 'RTErdogan', 'MevlutCavusoglu', 'ozdag', 'özdağ', 'TBMM','drfahrettinkoca', 'yenisafak', 'tayyip', 'cumhur', 'belediye', 'baskan', 'başkan', 'ulusal',
                    'odatv', 'suleyman', 'haskologlu', 'mansur', 'dbdevletbahceli', 'Ahmet_Davutoglu', 'babacan', 'gazetesozcu', 'imamoglu', 'imamoğlu', 'parlament', 'meclis',
                    'savaş', 'eğitim', 'egitim', 'dolar', 'lira', 'enflasyon', 'euro', 'döviz', 'altın', 'benzin', 'atama', 'altılı masa', 'abd', 'avrupa', 'almanya', 'nato',
                    'sınır', 'göçmen', 'gocmen', 'sığınmacı', 'mülteci', 'mahkeme', 'kanun', 'ukrayna', 'rusya', 'komisyon', 'fetö', 'faiz', 'piyasa', 'banka', 'politik', 'toplantı', 'çiftçi',
                    'saray', 'demokrasi', 'faşis', 'kemal', 'rejim', 'özgürlük', 'koalisyon', 'egemen', 'kurultay', 'danıştay', 'davutoğlu', 'birleşmiş milletler',
                    'bahçeli', 'diplomasi', 'cem uzan', 'lgbt', 'seçim', '2023', 'ibb', 'cemaat', 'soylu', 'liberal', 'kapital', 'protesto', 'halk']

        dfPolitical['tweet_id'].append(id_str)
        dfPolitical['is_retweet'].append(is_retweet)
        dfPolitical['retweeted_username'].append(retweeted_username)
        dfPolitical['text'].append(text)
        ctr = 0
        for ent in list_of_entities:
          if text.lower().find(ent) != -1:
            ctr = ctr + 1
        dfPolitical['check'].append(ctr)
        dfPolitical['num_mentions'].append(num_mentions)
        dfPolitical['num_hashtags'].append(num_hashtags)
        dfPolitical['num_retweets'].append(retweet_count)
        dfPolitical['num_favorites'].append(favorite_count)
        dfPolitical['user_id'].append(user_id_str)
        dfPolitical['user_screen_name'].append(screen_name)
        dfPolitical['user_description'].append(user_description)
        dfPolitical['user_verified'].append(user_verified)
        dfPolitical['user_follower'].append(user_follower)
        dfPolitical['user_following'].append(user_following)
        dfPolitical['user_num_of_tweets'].append(user_num_of_tweets)
        dfPolitical['num_political_entities'].append(num_political_entities)
        dfPolitical['total_interactions'].append(total_num_interactions)

# %%
dfPolitical = pd.DataFrame(dfPolitical)
dfPolitical
# Out:
#                   tweet_id  is_retweet retweeted_username  \
# 0      1588568792984346624           0               None
# 1      1588452263047069697           0               None
# 2      1569589330544398336           0               None
# 3      1570428119609139201           0               None
# 4      1551163840368414722           0               None
# ...                    ...         ...                ...
# 33528  1568595408233832448           0               None
# 33529  1584027427696959488           0               None
# 33530  1585945783307730945           0               None
# 33531  1569748909521801221           1       muazzezeralp
# 33532  1585926877675282432           0               None
#
#                                                     text  num_mentions  \
# 0      Sosyal Hizmetin temelini çocuk oluşturur,çocuğ...             0
# 1      @mahirunal Gavur İzmir ya onlar, hani Cumhuriy...             1
# 2      #ŞehitAdayıUzmÇvşaKadro\nSiz İstesenizde Istem...             0
# 3      @ajans_muhbir Siz kaypak olmayıp onay vermesey...             1
# 4      Engelli öğretmenler olarak önümüzdeki engeller...             0
# ...                                                  ...           ...
# 33528  Gerçek kimlik taşımayan hesaplara cevap vermem...             0
# 33529  @umitozdag Neden Suriyelilerle ilgili bu kadar...             1
# 33530  @celebimehmeta Niye Türkiye yüzyılıda.Türkiye ...             1
# 33531  RT @muazzezeralp: @Doan58213655 @denizkonur @N...             7
# 33532  @bybekirbozdag Yasal işlemlerdn dolayı( banka,...             1
#
#        num_hashtags  num_retweets  num_favorites              user_id  \
# 0                 0            49             98   920963718103650304
# 1                 0             0              0            595514060
# 2                 1             0              0  1356375754561490947
# 3                 0             0              0  1478775431008595968
# 4                 0             0              0  1511976696337113088
# ...             ...           ...            ...                  ...
# 33528             0             9             81            576247173
# 33529             0             1              8            162308585
# 33530             0             0              1            415025519
# 33531             1             6              0  1442125177727307781
# 33532             0             0              0  1180170443426320384
#
#       user_screen_name                                   user_description  \
# 0             maviruh_     shu/\nburaya afilli bir söz yazdığımı varsayın
# 1               mtfdan
# 2      ahsucilginuzman                                    Vatan Sevdalisi
# 3         hamitelkelle                                            HighOne
# 4          sed58417690
# ...                ...                                                ...
# 33528     ardanzenturk  RT ONAYLADIĞIM ANLAMINA GELMEZ\nArtık fikirler...
# 33529         ozgul_61      Bridge design engineer Yaay hesabı : dilfiruz
# 33530        ladrekova
# 33531  yapikytgrivrlsn
# 33532  rodrige62822813  Canı yanan sabretsin; can yakan da yanacağı gü...
#
#        user_verified  user_follower  user_following  user_num_of_tweets  \
# 0              False            284             539                2638
# 1              False            131             589                6647
# 2              False             60             118                2924
# 3              False              2              69                1783
# 4              False            119             166                7559
# ...              ...            ...             ...                 ...
# 33528          False         171399            4147               41342
# 33529          False           3936            3227               52340
# 33530          False            121             412                1225
# 33531          False            591            1003              153819
# 33532          False             65             536                5102
#
#        num_political_entities  total_interactions  check
# 0                           0                 147      1
# 1                           0                   0      1
# 2                           0                   0      2
# 3                           0                   0      1
# 4                           0                   0      0
# ...                       ...                 ...    ...
# 33528                       0                  90      0
# 33529                       1                   9      3
# 33530                       0                   1      2
# 33531                       1                   6      1
# 33532                       0                   0      2
#
# [33533 rows x 18 columns]

# %% [markdown]
# ## 1.2. From Users

# %% [markdown]
# ### 1.2.1. Get user metadata from user_profiles.jsons.gz

# %% [markdown]
# #### 1.2.1.1. Get user info metadata

# %%
def get_user_info_metadata(user_metadata_line):

    user_id = user_metadata_line['id_str']
    user_name = user_metadata_line['name']
    user_screen_name = user_metadata_line['screen_name'].lower()
    user_location = user_metadata_line['location']
    user_description = user_metadata_line['description']
    user_followers_count = user_metadata_line['followers_count']
    user_friends_count = user_metadata_line['friends_count']
    user_is_verified = user_metadata_line['verified']
    user_tweet_num = user_metadata_line['statuses_count']
    user_created_at = user_metadata_line['created_at']
    last4_created_at = int(user_created_at[-4:])
    if ((2022 - last4_created_at)*365 == 0):
      tweet_per_day = 0
    else:
      tweet_per_day = round(int(user_tweet_num) / ((2022 - last4_created_at)*365))
    user_favorites_count = user_metadata_line['favourites_count']
    user_is_translate = user_metadata_line['is_translation_enabled']
    user_extended_profile = user_metadata_line['has_extended_profile']

    dictionary = {'user_id':user_id, 'user_name': user_name, 'user_screen_name':user_screen_name, 'user_location':user_location,
     'user_description':user_description, 'user_followers_count':user_followers_count, 'user_friends_count':user_friends_count, 'user_is_verified':user_is_verified,
     'user_tweet_num':user_tweet_num, 'last4_created_at':last4_created_at, 'tweet_per_day':tweet_per_day, 'user_favorites_count':user_favorites_count, 'user_is_translate':user_is_translate,
     'user_extended_profile':user_extended_profile}

    return dictionary

# %% [markdown]
# #### 1.2.1.2. Get followers/(followers+friends) ratio

# %%
def get_followers_all_ratio(user_followers_count, user_friends_count):

    if user_friends_count + user_followers_count == 0:
        followers_all_ratio = 0

    else:
        followers_all_ratio =  user_followers_count / (user_friends_count + user_followers_count)

    return followers_all_ratio

# %% [markdown]
# #### 1.2.1.3. Get description length

# %%
def get_desc_len(user_description):

    description_len = len(user_description)

    return description_len

# %%
dfBot = {'user_id':[],
         'user_name':[],
         'user_screen_name':[],
         'user_location':[],
         'user_description':[],
         'user_followers_count':[],
         'user_friends_count':[],
         'description_len':[],
         'followers_to_all_ratio':[],
         'user_is_verified':[],
         'user_tweet_num':[],
         'last4_created_at':[],
         'tweet_per_day':[],
         'user_favorites_count':[],
         'user_is_translate':[],
         'user_extended_profile':[]}

with gzip.open(f"{PATH_TO_DOWNLOADED}user_profiles.jsons.gz", "rb") as f:
    for line in f:
        line = json.loads(line)

        dictionary = get_user_info_metadata(line)
        for k,v in dictionary.items():
            dfBot[k].append(v)


        # manually crafted data:
        description_len = get_desc_len(dictionary['user_description'])
        dfBot['description_len'].append(description_len)

        followers_all_ratio = get_followers_all_ratio(dictionary['user_followers_count'],
                                                      dictionary['user_friends_count'])

        dfBot['followers_to_all_ratio'].append(followers_all_ratio)

# %%
dfBot = pd.DataFrame(dfBot)
dfBot
# Out:
#                    user_id                                      user_name  \
# 0      1431241870848450577                            Nasreena Khan Wazir
# 1      1304340303080386560                                    fania :((((
# 2      1116042038577958914                                    Yusuf Aksoy
# 3               4859899931  Be (VIXX6) ama oppalarının düğününe gidemiyor
# 4               2225373636                                         SLMDMR
# ...                    ...                                            ...
# 29665  1320834618220781569                                        islammm
# 29666            111074128                                     Melda Onur
# 29667             36946875                                        ali ydm
# 29668           2389587396                                    Türkan Usta
# 29669           1575904134                                           ARAZ
#
#       user_screen_name            user_location  \
# 0      nasreenakhan006      Islamabad, Pakistan
# 1          scorpiehoez                   bogor
# 2      yusufak63712920
# 3       nedenburdaysam  Hufflepuff ortak salon
# 4          biologselim
# ...                ...                      ...
# 29665       islam_mrsj
# 29666        meldaonur
# 29667          ali_ydm        İstanbul, Türkiye
# 29668       turkanusta          Ankara, Türkiye
# 29669        ben121975
#
#                                         user_description  \
# 0                                                Student
# 1                                    have a holly jolly🎄
# 2      Bir şeyden pişmanlık duymak istemiyorsan,her ş...
# 3      SMStan\n/St☆rlight ///come on girls,this is ou...
# 4                               BİYOLOG🔬🦠\nNanoteknoloji
# ...                                                  ...
# 29665
# 29666  Şekersiz çay, etsiz sofra, SAVAŞSIZ dünya... 🐌...
# 29667                       hayat oyunsa bende jeton çok
# 29668  Ustaya sormuşlar; hayatta yaptığın en büyük is...
# 29669  Korkak gerçek le yüzleşmeyi redd eder,hırçınla...
#
#        user_followers_count  user_friends_count  description_len  \
# 0                        65                 185                7
# 1                      8235                3011               19
# 2                        95                 399               64
# 3                        40                  83               65
# 4                       100                  98               23
# ...                     ...                 ...              ...
# 29665                   229                 217                0
# 29666                212457                5428              100
# 29667                   116                 141               28
# 29668                  1669                3639              116
# 29669                  6026                5625              158
#
#        followers_to_all_ratio  user_is_verified  user_tweet_num  \
# 0                    0.260000             False            2551
# 1                    0.732260             False           42771
# 2                    0.192308             False           14300
# 3                    0.325203             False           21303
# 4                    0.505051             False            1629
# ...                       ...               ...             ...
# 29665                0.513453             False            2396
# 29666                0.975088             False           75178
# 29667                0.451362             False            6482
# 29668                0.314431             False          121113
# 29669                0.517209             False            7120
#
#        last4_created_at  tweet_per_day  user_favorites_count  \
# 0                  2021              7                 17676
# 1                  2020             59                 15474
# 2                  2019             13                 18220
# 3                  2016             10                 26999
# 4                  2013              0                  2179
# ...                 ...            ...                   ...
# 29665              2020              3                 10820
# 29666              2010             17                 36671
# 29667              2009              1                  7389
# 29668              2014             41                140095
# 29669              2013              2                 39605
#
#        user_is_translate  user_extended_profile
# 0                  False                   True
# 1                  False                   True
# 2                  False                   True
# 3                  False                  False
# 4                  False                  False
# ...                  ...                    ...
# 29665              False                  False
# 29666              False                   True
# 29667              False                  False
# 29668              False                   True
# 29669              False                  False
#
# [29670 rows x 16 columns]

# %% [markdown]
# ### 1.2.2. Get Tweet Info of Users in user_profiles.jsons.gz

# %% [markdown]
# #### 1.2.2.1. Check ratio of retweets to all tweets

# %%
def get_retweet_tweet_ratio(line):
    number_retweets = 0
    number_original_tweets = 0

    for tweet in line['tweets']:
        try:
            tweet['retweeted_status']
            number_retweets += 1

        except:
            number_original_tweets += 1

    total_tweets = number_retweets + number_original_tweets

    if total_tweets == 0:
        retweet_total_ratio = None
    else:
        retweet_total_ratio = number_retweets/(total_tweets)

    return retweet_total_ratio, total_tweets

# %% [markdown]
# #### 1.2.2.2. Check median number of favorites

# %%
def get_median_number_favorites(line):
    num_median_favorites = np.median([tweet['favorite_count'] for tweet in line['tweets']])

    return num_median_favorites

# %% [markdown]
# ### 1.2.3. Collect data using the functions above and transform into a Pandas DataFrame

# %%
dfBotTweets = {'user_id':[],
               'retweet_total_ratio':[],
               'num_median_favorites':[],
               'num_of_tweets':[]}

i = 0

with gzip.open(f"{PATH_TO_DOWNLOADED}user_tweets.jsons.gz", "rb") as f:
    for line in f:

        line = json.loads(line)

        user_id = line['user_id']
        dfBotTweets['user_id'].append(user_id)

        retweet_total_ratio, num_of_tweets = get_retweet_tweet_ratio(line)
        dfBotTweets['retweet_total_ratio'].append(retweet_total_ratio)
        dfBotTweets['num_of_tweets'].append(num_of_tweets)

        num_median_favorites = get_median_number_favorites(line)
        dfBotTweets['num_median_favorites'].append(num_median_favorites)

        i += 1

        if i % 10000 == 0:
            print(i)
# Out:
# /usr/local/lib/python3.8/dist-packages/numpy/core/fromnumeric.py:3440: RuntimeWarning: Mean of empty slice.
#   return _methods._mean(a, axis=axis, dtype=dtype,
# /usr/local/lib/python3.8/dist-packages/numpy/core/_methods.py:189: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)
# 10000
# 20000

# %%
dfBotTweets = pd.DataFrame(dfBotTweets)
dfBotTweets
# Out:
#                    user_id  retweet_total_ratio  num_median_favorites  \
# 0                594642154             0.115000                   2.0
# 1                525600289             0.005025                   1.0
# 2       931895965501534209             0.900000                   0.0
# 3      1591543462746329088             0.185000                   0.0
# 4       734801354749796352             1.000000                   0.0
# ...                    ...                  ...                   ...
# 28310  1591370361488252928             0.800000                   0.0
# 28311  1475272459616235525             0.825000                   0.0
# 28312  1096753792731750401             0.051020                   1.0
# 28313  1269527617687953409             0.095000                   2.0
# 28314  1483177252271570944             0.630000                   0.0
#
#        num_of_tweets
# 0                200
# 1                199
# 2                200
# 3                200
# 4                200
# ...              ...
# 28310            200
# 28311            200
# 28312            196
# 28313            200
# 28314            200
#
# [28315 rows x 4 columns]

# %% [markdown]
# ### 1.2.3. Merge dfBot and dfBotTweets

# %%
dfBotAll = dfBot.merge(dfBotTweets,
                       how='left')

dfBotAll[['retweet_total_ratio', 'num_median_favorites']] = dfBotAll[['retweet_total_ratio', 'num_median_favorites']].fillna(dfBotAll[['retweet_total_ratio', 'num_median_favorites']].median())

dfBotAll
# Out:
#                    user_id                                      user_name  \
# 0      1431241870848450577                            Nasreena Khan Wazir
# 1      1304340303080386560                                    fania :((((
# 2      1116042038577958914                                    Yusuf Aksoy
# 3               4859899931  Be (VIXX6) ama oppalarının düğününe gidemiyor
# 4               2225373636                                         SLMDMR
# ...                    ...                                            ...
# 29665  1320834618220781569                                        islammm
# 29666            111074128                                     Melda Onur
# 29667             36946875                                        ali ydm
# 29668           2389587396                                    Türkan Usta
# 29669           1575904134                                           ARAZ
#
#       user_screen_name            user_location  \
# 0      nasreenakhan006      Islamabad, Pakistan
# 1          scorpiehoez                   bogor
# 2      yusufak63712920
# 3       nedenburdaysam  Hufflepuff ortak salon
# 4          biologselim
# ...                ...                      ...
# 29665       islam_mrsj
# 29666        meldaonur
# 29667          ali_ydm        İstanbul, Türkiye
# 29668       turkanusta          Ankara, Türkiye
# 29669        ben121975
#
#                                         user_description  \
# 0                                                Student
# 1                                    have a holly jolly🎄
# 2      Bir şeyden pişmanlık duymak istemiyorsan,her ş...
# 3      SMStan\n/St☆rlight ///come on girls,this is ou...
# 4                               BİYOLOG🔬🦠\nNanoteknoloji
# ...                                                  ...
# 29665
# 29666  Şekersiz çay, etsiz sofra, SAVAŞSIZ dünya... 🐌...
# 29667                       hayat oyunsa bende jeton çok
# 29668  Ustaya sormuşlar; hayatta yaptığın en büyük is...
# 29669  Korkak gerçek le yüzleşmeyi redd eder,hırçınla...
#
#        user_followers_count  user_friends_count  description_len  \
# 0                        65                 185                7
# 1                      8235                3011               19
# 2                        95                 399               64
# 3                        40                  83               65
# 4                       100                  98               23
# ...                     ...                 ...              ...
# 29665                   229                 217                0
# 29666                212457                5428              100
# 29667                   116                 141               28
# 29668                  1669                3639              116
# 29669                  6026                5625              158
#
#        followers_to_all_ratio  user_is_verified  user_tweet_num  \
# 0                    0.260000             False            2551
# 1                    0.732260             False           42771
# 2                    0.192308             False           14300
# 3                    0.325203             False           21303
# 4                    0.505051             False            1629
# ...                       ...               ...             ...
# 29665                0.513453             False            2396
# 29666                0.975088             False           75178
# 29667                0.451362             False            6482
# 29668                0.314431             False          121113
# 29669                0.517209             False            7120
#
#        last4_created_at  tweet_per_day  user_favorites_count  \
# 0                  2021              7                 17676
# 1                  2020             59                 15474
# 2                  2019             13                 18220
# 3                  2016             10                 26999
# 4                  2013              0                  2179
# ...                 ...            ...                   ...
# 29665              2020              3                 10820
# 29666              2010             17                 36671
# 29667              2009              1                  7389
# 29668              2014             41                140095
# 29669              2013              2                 39605
#
#        user_is_translate  user_extended_profile  retweet_total_ratio  \
# 0                  False                   True             0.395939
# 1                  False                   True             0.125000
# 2                  False                   True             0.910000
# 3                  False                  False             0.015306
# 4                  False                  False             0.659898
# ...                  ...                    ...                  ...
# 29665              False                  False             0.015000
# 29666              False                   True             0.291457
# 29667              False                  False             0.061538
# 29668              False                   True             0.995000
# 29669              False                  False             0.030000
#
#        num_median_favorites  num_of_tweets
# 0                       0.0          197.0
# 1                       0.0          200.0
# 2                       0.0          200.0
# 3                       1.0          196.0
# 4                       0.0          197.0
# ...                     ...            ...
# 29665                   1.0          200.0
# 29666                   2.0          199.0
# 29667                   0.0          195.0
# 29668                   0.0          200.0
# 29669                   1.0          200.0
#
# [29670 rows x 19 columns]

# %% [markdown]
# # 2. TRAIN MODEL

# %% [markdown]
# ## 2.1. Political Tweet Prediction

# %% [markdown]
# ### 2.1.1. Merge dfPolitical data with labels

# %%
dfPoliticalAll_train = dfPolitical.merge(trainingTweetDf,
                                         on='tweet_id')
dfPoliticalAll_train['user_verified'] = dfPoliticalAll_train['user_verified']*1
dfPoliticalAll_train.head()
# Out:
#               tweet_id  is_retweet retweeted_username  \
# 0  1585955683513798656           0               None
# 1  1597631718479261696           0               None
# 2  1572522789948751874           0               None
# 3  1591412481561624577           0               None
# 4  1596914274907348992           0               None
#
#                                                 text  num_mentions  \
# 0  @AvOzlemZengin YüzüncüYıla YakışanGenelAf adli...             1
# 1  #TCYüzyılıÜcretliÖgrtKadro\n#TCYüzyılıÜcretliÖ...             0
# 2  Ekrem İmamoğlu davayı değerlendirdi. 'Boş işle...             0
# 3  Sayın Bakanım @suleymansoylu POMEM önlisans er...             1
# 4  @varank Sayın bakanım,  Bodrumdaki bu araziyi ...             1
#
#    num_hashtags  num_retweets  num_favorites              user_id  \
# 0             0             3              2  1564992353168941058
# 1             2            30             28  1324630334416297985
# 2             0             5             66            407597071
# 3             0             0              0  1394789887073738753
# 4             0             0              0  1586083256088371201
#
#   user_screen_name                                   user_description  \
# 0    zehra78231638
# 1       nurozguler
# 2        onediocom  Türkiye'nin ilk ve tek sosyal içerik sitesi ht...
# 3    buckybarnestr                                                ...
# 4      sayariahmet
#
#    user_verified  user_follower  user_following  user_num_of_tweets  \
# 0              0            221             113               25730
# 1              0            455             420               12427
# 2              1         735643              12              161123
# 3              0             10              45                1595
# 4              0              6               6                1251
#
#    num_political_entities  total_interactions  check isPolitical
# 0                       0                   5      0         Yes
# 1                       0                  58      0         Yes
# 2                       0                  71      0         Yes
# 3                       1                   0      3         Yes
# 4                       0                   0      1         Yes

# %% [markdown]
# ### 2.1.2. Separate X and y values
# We only use 3 features here to create a baseline model. However, it is not enough to get good results.

# %%
#X = dfPoliticalAll_train[['num_political_entities']]

X = dfPoliticalAll_train[['num_mentions','num_hashtags','num_retweets','user_follower','user_following','user_verified','user_num_of_tweets','num_political_entities','total_interactions']]
y = dfPoliticalAll_train['isPolitical'].apply(lambda x: 1 if x=='Yes' else 0)

# %% [markdown]
# ### 2.1.3. Train - validation split

# %%
from sklearn.model_selection import train_test_split

X_train, X_valid, y_train, y_valid = train_test_split(X, y, test_size=0.20, random_state=42)

# %% [markdown]
# ### 2.1.4. Train the model
#
# Here, you may use different models such as neural networks, XGBoost, AdaBoost, RandomForest, Linear Regression, Logistic Regression etc. to see which model does the best. Also, you can use grid_search_cv() or a basic for loop to optimize the hyperparameters of your model.

# %%
X_dfPoliticalAll_train = X
y_dfPoliticalAll_train = y

from sklearn.preprocessing import MinMaxScaler
msc = MinMaxScaler(feature_range=(0, 1))
scaledP_Xtrain = msc.fit_transform(X_dfPoliticalAll_train)
scaledP_Xtrain_df = pd.DataFrame(scaledP_Xtrain, columns=X_dfPoliticalAll_train.columns.values)
scaledP_ytrain_df = y_dfPoliticalAll_train.astype(float)

pX_train, pX_valid, py_train, py_valid = train_test_split(scaledP_Xtrain_df, scaledP_ytrain_df, test_size=0.20, random_state=42)

# %%
import keras
import keras.utils
from tensorflow.keras import utils as np_utils
from tensorflow.keras.utils import to_categorical
from keras.models import Sequential
from keras.layers import Dense, Dropout, Activation, Flatten
from tensorflow.keras.optimizers import SGD, Adam
import tensorflow as tf

# %%
## UTKU

model_1 = tf.keras.Sequential()
model_1.add(tf.keras.layers.Dense(100, activation='relu', name='hidden_layer_1'))
model_1.add(tf.keras.layers.Dense(50, activation='relu', name='hidden_layer_2'))
model_1.add(tf.keras.layers.Dense(25, activation='relu', name='hidden_layer_3'))
model_1.add(tf.keras.layers.Dense(1, name='output_layer'))

# compile your model with an optimizer
model_1.compile(loss='mean_squared_error', optimizer = Adam(learning_rate=0.001), metrics=['mse','accuracy'])

# fit the model on training data
pX = pX_train.values
pY = py_train.values
model_1.fit(pX, pY, epochs=35, batch_size=64, shuffle=True, verbose=1)
# Out:
# Epoch 1/35
# 38/38 [==============================] - 2s 3ms/step - loss: 0.3973 - mse: 0.3973 - accuracy: 0.4421
# Epoch 2/35
# 38/38 [==============================] - 0s 3ms/step - loss: 0.2088 - mse: 0.2088 - accuracy: 0.6946
# Epoch 3/35
# 38/38 [==============================] - 0s 2ms/step - loss: 0.2005 - mse: 0.2005 - accuracy: 0.6754
# Epoch 4/35
# 38/38 [==============================] - 0s 3ms/step - loss: 0.1964 - mse: 0.1964 - accuracy: 0.6992
# Epoch 5/35
# 38/38 [==============================] - 0s 3ms/step - loss: 0.1936 - mse: 0.1936 - accuracy: 0.7225
# Epoch 6/35
# 38/38 [==============================] - 0s 3ms/step - loss: 0.1927 - mse: 0.1927 - accuracy: 0.7092
# Epoch 7/35
# 38/38 [==============================] - 0s 3ms/step - loss: 0.1901 - mse: 0.1901 - accuracy: 0.7179
# Epoch 8/35
# 38/38 [==============================] - 0s 3ms/step - loss: 0.1902 - mse: 0.1902 - accuracy: 0.7179
# Epoch 9/35
# 38/38 [==============================] - 0s 3ms/step - loss: 0.1887 - mse: 0.1887 - accuracy: 0.7221
# Epoch 10/35
# 38/38 [==============================] - 0s 3ms/step - loss: 0.1889 - mse: 0.1889 - accuracy: 0.7192
# Epoch 11/35
# 38/38 [==============================] - 0s 3ms/step - loss: 0.1885 - mse: 0.1885 - accuracy: 0.7237
# Epoch 12/35
# 38/38 [==============================] - 0s 3ms/step - loss: 0.1880 - mse: 0.1880 - accuracy: 0.7183
# Epoch 13/35
# 38/38 [==============================] - 0s 3ms/step - loss: 0.1873 - mse: 0.1873 - accuracy: 0.7237
# Epoch 14/35
# 38/38 [==============================] - 0s 3ms/step - loss: 0.1888 - mse: 0.1888 - accuracy: 0.7221
# Epoch 15/35
# 38/38 [==============================] - 0s 3ms/step - loss: 0.1867 - mse: 0.1867 - accuracy: 0.7242
# Epoch 16/35
# 38/38 [==============================] - 0s 3ms/step - loss: 0.1868 - mse: 0.1868 - accuracy: 0.7217
# Epoch 17/35
# 38/38 [==============================] - 0s 3ms/step - loss: 0.1863 - mse: 0.1863 - accuracy: 0.7237
# Epoch 18/35
# 38/38 [==============================] - 0s 2ms/step - loss: 0.1867 - mse: 0.1867 - accuracy: 0.7237
# Epoch 19/35
# 38/38 [==============================] - 0s 3ms/step - loss: 0.1865 - mse: 0.1865 - accuracy: 0.7246
# Epoch 20/35
# 38/38 [==============================] - 0s 3ms/step - loss: 0.1864 - mse: 0.1864 - accuracy: 0.7237
# Epoch 21/35
# 38/38 [==============================] - 0s 3ms/step - loss: 0.1870 - mse: 0.1870 - accuracy: 0.7237
# Epoch 22/35
# 38/38 [==============================] - 0s 3ms/step - loss: 0.1865 - mse: 0.1865 - accuracy: 0.7233
# Epoch 23/35
# 38/38 [==============================] - 0s 3ms/step - loss: 0.1852 - mse: 0.1852 - accuracy: 0.7262
# Epoch 24/35
# 38/38 [==============================] - 0s 3ms/step - loss: 0.1869 - mse: 0.1869 - accuracy: 0.7212
# Epoch 25/35
# 38/38 [==============================] - 0s 3ms/step - loss: 0.1855 - mse: 0.1855 - accuracy: 0.7275
# Epoch 26/35
# 38/38 [==============================] - 0s 2ms/step - loss: 0.1852 - mse: 0.1852 - accuracy: 0.7233
# Epoch 27/35
# 38/38 [==============================] - 0s 2ms/step - loss: 0.1858 - mse: 0.1858 - accuracy: 0.7283
# Epoch 28/35
# 38/38 [==============================] - 0s 3ms/step - loss: 0.1850 - mse: 0.1850 - accuracy: 0.7279
# Epoch 29/35
# 38/38 [==============================] - 0s 2ms/step - loss: 0.1865 - mse: 0.1865 - accuracy: 0.7267
# Epoch 30/35
# 38/38 [==============================] - 0s 3ms/step - loss: 0.1847 - mse: 0.1847 - accuracy: 0.7279
# Epoch 31/35
# 38/38 [==============================] - 0s 3ms/step - loss: 0.1855 - mse: 0.1855 - accuracy: 0.7271
# Epoch 32/35
# 38/38 [==============================] - 0s 3ms/step - loss: 0.1850 - mse: 0.1850 - accuracy: 0.7283
# Epoch 33/35
# 38/38 [==============================] - 0s 3ms/step - loss: 0.1848 - mse: 0.1848 - accuracy: 0.7279
# Epoch 34/35
# 38/38 [==============================] - 0s 3ms/step - loss: 0.1843 - mse: 0.1843 - accuracy: 0.7308
# Epoch 35/35
# 38/38 [==============================] - 0s 2ms/step - loss: 0.1833 - mse: 0.1833 - accuracy: 0.7300

# %%
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import accuracy_score, confusion_matrix, mean_squared_error
from sklearn.model_selection import GridSearchCV


# create an instance of the RandomForestClassifier
rfc_pol = RandomForestClassifier()

# fit the model to the training data
rfc_pol.fit(X_train, y_train)

# make predictions on the validation set
preds = rfc_pol.predict(X_valid)

# evaluate on validation set
acc_score = accuracy_score(y_valid, preds)
confusion = confusion_matrix(y_valid, preds)
mse = mean_squared_error(y_valid, preds)

print("MSE:", mse, "\n",
      "Accuracy Score:", acc_score, "\n",
      "Confusion Matrix:", "\n", confusion)
# Out:
# MSE: 0.2633333333333333
#  Accuracy Score: 0.7366666666666667
#  Confusion Matrix:
#  [[ 98 111]
#  [ 47 344]]

# %%
## BRN

from sklearn.tree import DecisionTreeClassifier
from sklearn.model_selection import GridSearchCV
from sklearn.metrics import accuracy_score, confusion_matrix, mean_squared_error

# create an instance
dtc = DecisionTreeClassifier()

param_grid = {'max_depth':[6]}

grid = GridSearchCV(dtc,
                    param_grid,
                    cv=5,
                    scoring='accuracy',
                    return_train_score=False,
                    verbose=1,
                    refit=True)

# fit your model
dtc_political = grid.fit(X_train, y_train)
#dtc_political.fit(X_train, y_train)

# make predictions
preds = dtc_political.predict(X_valid)

# evaluate on validation set
acc_score = accuracy_score(y_valid, preds)
confusion = confusion_matrix(y_valid, preds)
mse = mean_squared_error(y_valid, preds)

print("MSE:", mse, "\n",
      "Accuracy Score:", acc_score, "\n",
      "Confusion Matrix:", "\n", confusion)
# Out:
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# MSE: 0.28833333333333333
#  Accuracy Score: 0.7116666666666667
#  Confusion Matrix:
#  [[ 64 145]
#  [ 28 363]]

# %%
dtc_political = Sequential()
dtc_political.add(Flatten())

dtc_political.add(Dense(250, activation='sigmoid'))
dtc_political.add(Dense(100, activation='sigmoid'))
dtc_political.add(Dense(1, activation='sigmoid'))#out

# compile your model with an optimizer
dtc_political.compile(loss='mean_squared_error', optimizer=Adam())

dtc_political.fit(X_train, y_train, batch_size=64, epochs=30, validation_split = 0.2, verbose=0)

score = dtc_political.evaluate(X_valid, y_valid)
print('MSE score:', score)
# Out:
# 19/19 [==============================] - 0s 2ms/step - loss: 0.2276
# MSE score: 0.22758738696575165

# %%
model_1 = tf.keras.Sequential()
model_1.add(tf.keras.layers.Dense(200, activation='relu', name='hidden_layer_1'))
model_1.add(tf.keras.layers.Dense(150, activation='relu', name='hidden_layer_2'))
model_1.add(tf.keras.layers.Dense(100, activation='relu', name='hidden_layer_3'))
model_1.add(tf.keras.layers.Dense(75, activation='relu', name='hidden_layer_4'))

model_1.add(tf.keras.layers.Dense(1, name='output_layer'))

# compile your model with an optimizer
model_1.compile(loss='mean_squared_error', optimizer = 'adam', metrics=['mse','accuracy'])

# fit the model on training data
pX = pX_train.values
pY = py_train.values
model_1.fit(pX, pY, epochs=50, batch_size=64, shuffle=True, verbose=1)
# Out:
# Epoch 1/50
# 38/38 [==============================] - 1s 5ms/step - loss: 0.2764 - mse: 0.2764 - accuracy: 0.6379
# Epoch 2/50
# 38/38 [==============================] - 0s 4ms/step - loss: 0.1772 - mse: 0.1772 - accuracy: 0.7563
# Epoch 3/50
# 38/38 [==============================] - 0s 4ms/step - loss: 0.1678 - mse: 0.1678 - accuracy: 0.7567
# Epoch 4/50
# 38/38 [==============================] - 0s 4ms/step - loss: 0.1621 - mse: 0.1621 - accuracy: 0.7542
# Epoch 5/50
# 38/38 [==============================] - 0s 5ms/step - loss: 0.1600 - mse: 0.1600 - accuracy: 0.7596
# Epoch 6/50
# 38/38 [==============================] - 0s 5ms/step - loss: 0.1612 - mse: 0.1612 - accuracy: 0.7617
# Epoch 7/50
# 38/38 [==============================] - 0s 4ms/step - loss: 0.1603 - mse: 0.1603 - accuracy: 0.7542
# Epoch 8/50
# 38/38 [==============================] - 0s 5ms/step - loss: 0.1576 - mse: 0.1576 - accuracy: 0.7667
# Epoch 9/50
# 38/38 [==============================] - 0s 4ms/step - loss: 0.1607 - mse: 0.1607 - accuracy: 0.7579
# Epoch 10/50
# 38/38 [==============================] - 0s 4ms/step - loss: 0.1572 - mse: 0.1572 - accuracy: 0.7671
# Epoch 11/50
# 38/38 [==============================] - 0s 4ms/step - loss: 0.1570 - mse: 0.1570 - accuracy: 0.7713
# Epoch 12/50
# 38/38 [==============================] - 0s 5ms/step - loss: 0.1571 - mse: 0.1571 - accuracy: 0.7633
# Epoch 13/50
# 38/38 [==============================] - 0s 4ms/step - loss: 0.1573 - mse: 0.1573 - accuracy: 0.7696
# Epoch 14/50
# 38/38 [==============================] - 0s 5ms/step - loss: 0.1581 - mse: 0.1581 - accuracy: 0.7588
# Epoch 15/50
# 38/38 [==============================] - 0s 4ms/step - loss: 0.1555 - mse: 0.1555 - accuracy: 0.7704
# Epoch 16/50
# 38/38 [==============================] - 0s 4ms/step - loss: 0.1556 - mse: 0.1556 - accuracy: 0.7625
# Epoch 17/50
# 38/38 [==============================] - 0s 5ms/step - loss: 0.1554 - mse: 0.1554 - accuracy: 0.7700
# Epoch 18/50
# 38/38 [==============================] - 0s 4ms/step - loss: 0.1553 - mse: 0.1553 - accuracy: 0.7713
# Epoch 19/50
# 38/38 [==============================] - 0s 5ms/step - loss: 0.1551 - mse: 0.1551 - accuracy: 0.7683
# Epoch 20/50
# 38/38 [==============================] - 0s 5ms/step - loss: 0.1553 - mse: 0.1553 - accuracy: 0.7646
# Epoch 21/50
# 38/38 [==============================] - 0s 4ms/step - loss: 0.1538 - mse: 0.1538 - accuracy: 0.7683
# Epoch 22/50
# 38/38 [==============================] - 0s 4ms/step - loss: 0.1555 - mse: 0.1555 - accuracy: 0.7663
# Epoch 23/50
# 38/38 [==============================] - 0s 5ms/step - loss: 0.1557 - mse: 0.1557 - accuracy: 0.7700
# Epoch 24/50
# 38/38 [==============================] - 0s 4ms/step - loss: 0.1558 - mse: 0.1558 - accuracy: 0.7733
# Epoch 25/50
# 38/38 [==============================] - 0s 4ms/step - loss: 0.1548 - mse: 0.1548 - accuracy: 0.7671
# Epoch 26/50
# 38/38 [==============================] - 0s 5ms/step - loss: 0.1519 - mse: 0.1519 - accuracy: 0.7779
# Epoch 27/50
# 38/38 [==============================] - 0s 5ms/step - loss: 0.1544 - mse: 0.1544 - accuracy: 0.7696
# Epoch 28/50
# 38/38 [==============================] - 0s 4ms/step - loss: 0.1524 - mse: 0.1524 - accuracy: 0.7704
# Epoch 29/50
# 38/38 [==============================] - 0s 4ms/step - loss: 0.1538 - mse: 0.1538 - accuracy: 0.7742
# Epoch 30/50
# 38/38 [==============================] - 0s 4ms/step - loss: 0.1520 - mse: 0.1520 - accuracy: 0.7700
# Epoch 31/50
# 38/38 [==============================] - 0s 4ms/step - loss: 0.1527 - mse: 0.1527 - accuracy: 0.7771
# Epoch 32/50
# 38/38 [==============================] - 0s 5ms/step - loss: 0.1518 - mse: 0.1518 - accuracy: 0.7742
# Epoch 33/50
# 38/38 [==============================] - 0s 4ms/step - loss: 0.1526 - mse: 0.1526 - accuracy: 0.7729
# Epoch 34/50
# 38/38 [==============================] - 0s 5ms/step - loss: 0.1515 - mse: 0.1515 - accuracy: 0.7721
# Epoch 35/50
# 38/38 [==============================] - 0s 5ms/step - loss: 0.1519 - mse: 0.1519 - accuracy: 0.7725
# Epoch 36/50
# 38/38 [==============================] - 0s 4ms/step - loss: 0.1510 - mse: 0.1510 - accuracy: 0.7850
# Epoch 37/50
# 38/38 [==============================] - 0s 4ms/step - loss: 0.1516 - mse: 0.1516 - accuracy: 0.7767
# Epoch 38/50
# 38/38 [==============================] - 0s 5ms/step - loss: 0.1515 - mse: 0.1515 - accuracy: 0.7750
# Epoch 39/50
# 38/38 [==============================] - 0s 4ms/step - loss: 0.1513 - mse: 0.1513 - accuracy: 0.7758
# Epoch 40/50
# 38/38 [==============================] - 0s 5ms/step - loss: 0.1498 - mse: 0.1498 - accuracy: 0.7788
# Epoch 41/50
# 38/38 [==============================] - 0s 5ms/step - loss: 0.1497 - mse: 0.1497 - accuracy: 0.7775
# Epoch 42/50
# 38/38 [==============================] - 0s 4ms/step - loss: 0.1500 - mse: 0.1500 - accuracy: 0.7788
# Epoch 43/50
# 38/38 [==============================] - 0s 4ms/step - loss: 0.1521 - mse: 0.1521 - accuracy: 0.7679
# Epoch 44/50
# 38/38 [==============================] - 0s 5ms/step - loss: 0.1508 - mse: 0.1508 - accuracy: 0.7767
# Epoch 45/50
# 38/38 [==============================] - 0s 4ms/step - loss: 0.1496 - mse: 0.1496 - accuracy: 0.7788
# Epoch 46/50
# 38/38 [==============================] - 0s 5ms/step - loss: 0.1498 - mse: 0.1498 - accuracy: 0.7796
# Epoch 47/50
# 38/38 [==============================] - 0s 5ms/step - loss: 0.1499 - mse: 0.1499 - accuracy: 0.7771
# Epoch 48/50
# 38/38 [==============================] - 0s 4ms/step - loss: 0.1506 - mse: 0.1506 - accuracy: 0.7713
# Epoch 49/50
# 38/38 [==============================] - 0s 4ms/step - loss: 0.1500 - mse: 0.1500 - accuracy: 0.7783
# Epoch 50/50
# 38/38 [==============================] - 0s 4ms/step - loss: 0.1488 - mse: 0.1488 - accuracy: 0.7775

# %%
dfBotAll.user_screen_name = dfBotAll.user_screen_name.str.lower()

# %%
dfBotAll_train = dfBotAll.merge(trainingUserDf,
                               left_on='user_screen_name',
                               right_on='screen_name')

dfBotAll_train['user_is_verified'] = dfBotAll_train['user_is_verified']*1
dfBotAll_train['user_is_translate'] = dfBotAll_train['user_is_translate']*1
dfBotAll_train['user_extended_profile'] = dfBotAll_train['user_extended_profile']*1

dfBotAll_train
# Out:
#                   user_id                 user_name user_screen_name  \
# 0     1512081815292432394                    sezgin  sezgin953116371
# 1     1425452291428077571                  Adem Koç       gogoadem61
# 2               328164303         Necmettin Balıkçı         dewil511
# 3     1343666971368431622              Night Bird⁷🦉   midnight__bird
# 4     1240932880488038400             Samed Pınarcı     samedpinarci
# ...                   ...                       ...              ...
# 2995  1286770207134973954            Hamide Arabacı         anka6054
# 2996  1598032338323214338      atamabekleyenbahceci  atamabekleyenzz
# 2997   760235343966863360                Emrah İNCİ       memrahinci
# 2998  1553973684100124672                 Murat Kkk       muratkkk18
# 2999  1392390985645281283  Münferit Fenerbahçeliler  mnferitfenerba1
#
#            user_location                                   user_description  \
# 0
# 1
# 2
# 3                          La vie est un sommeil, l’amour en est le rêve...
# 4                         Orman Mühendisi - Orman İşletme Şefi - Orman G...
# ...                  ...                                                ...
# 2995
# 2996
# 2997  Istanbul - Bayburt  Researcher | Middle East | Political Science |...
# 2998                                             Normal sıradan bir insanım
# 2999                      Fenerbahçe S.K. Kongre Üyesi Kırmızı çizgileri...
#
#       user_followers_count  user_friends_count  description_len  \
# 0                       46                 430                0
# 1                       14                 171                0
# 2                       21                  49                0
# 3                      422                 260               48
# 4                      133                 202               60
# ...                    ...                 ...              ...
# 2995                   151                  61                0
# 2996                   173                 367                0
# 2997                  5863                5905               71
# 2998                     1                  10               26
# 2999                   281                 270              156
#
#       followers_to_all_ratio  user_is_verified  user_tweet_num  \
# 0                   0.096639                 0            1535
# 1                   0.075676                 0             113
# 2                   0.300000                 0             219
# 3                   0.618768                 0           15191
# 4                   0.397015                 0            3734
# ...                      ...               ...             ...
# 2995                0.712264                 0            5288
# 2996                0.320370                 0             311
# 2997                0.498215                 0            1029
# 2998                0.090909                 0              18
# 2999                0.509982                 0            7165
#
#       last4_created_at  tweet_per_day  user_favorites_count  \
# 0                 2022              0                  9627
# 1                 2021              0                    74
# 2                 2011              0                    25
# 3                 2020             21                 84933
# 4                 2020              5                 15783
# ...                ...            ...                   ...
# 2995              2020              7                  5347
# 2996              2022              0                   196
# 2997              2016              0                   725
# 2998              2022              0                    38
# 2999              2021             20                  4106
#
#       user_is_translate  user_extended_profile  retweet_total_ratio  \
# 0                     0                      1             0.050251
# 1                     0                      1             0.761062
# 2                     0                      0             0.010101
# 3                     0                      1             0.085000
# 4                     0                      1             0.780000
# ...                 ...                    ...                  ...
# 2995                  0                      1             0.000000
# 2996                  0                      1             0.580000
# 2997                  0                      1             0.040000
# 2998                  0                      1             0.769231
# 2999                  0                      1             0.045000
#
#       num_median_favorites  num_of_tweets      screen_name isBot
# 0                      0.0          199.0  sezgin953116371    No
# 1                      0.0          113.0       gogoadem61    No
# 2                      0.0          198.0         dewil511   Yes
# 3                      1.0          200.0   midnight__bird    No
# 4                      0.0          200.0     samedpinarci    No
# ...                    ...            ...              ...   ...
# 2995                   1.0          200.0         anka6054    No
# 2996                   0.0          200.0  atamabekleyenzz    No
# 2997                  36.0          200.0       memrahinci    No
# 2998                   0.0           13.0       muratkkk18    No
# 2999                   1.0          200.0  mnferitfenerba1    No
#
# [3000 rows x 21 columns]

# %%
trainingUserDf.isBot.value_counts()
# Out:
# No     2424
# Yes     576
# Name: isBot, dtype: int64

# %%
X = dfBotAll_train[['user_followers_count', 'user_friends_count', 'description_len', 'followers_to_all_ratio', 'user_is_verified', 'user_tweet_num', 'tweet_per_day', 'user_favorites_count', 'user_is_translate', 'user_extended_profile', 'retweet_total_ratio', 'num_median_favorites']]
y = dfBotAll_train.isBot.apply(lambda x: 1 if x=='Yes' else 0)

# %%
#Model with neural network
X_dfBotAll_train = X
y_dfBotAll_train = y

from sklearn.preprocessing import MinMaxScaler
msc = MinMaxScaler(feature_range=(0, 1))
scaled_Xtrain = msc.fit_transform(X_dfBotAll_train)
scaled_Xtrain_df = pd.DataFrame(scaled_Xtrain, columns=X_dfBotAll_train.columns.values)
scaled_ytrain_df = y_dfBotAll_train.astype(float)

nX_train, nX_valid, ny_train, ny_valid = train_test_split(scaled_Xtrain_df, scaled_ytrain_df, test_size=0.20, random_state=42)

# %%
import keras
import keras.utils
from tensorflow.keras import utils as np_utils
from tensorflow.keras.utils import to_categorical
from keras.models import Sequential
from keras.layers import Dense, Dropout, Activation, Flatten
from tensorflow.keras.optimizers import SGD, Adam
import tensorflow as tf

# %%
model_2 = tf.keras.Sequential()
model_2.add(tf.keras.layers.Dense(200, activation='relu', name='hidden_layer_1'))
model_2.add(tf.keras.layers.Dense(150, activation='relu', name='hidden_layer_2'))
model_2.add(tf.keras.layers.Dense(100, activation='relu', name='hidden_layer_3'))
model_2.add(tf.keras.layers.Dense(75, activation='relu', name='hidden_layer_4'))
model_2.add(tf.keras.layers.Dense(1, name='output_layer'))

# compile your model with an optimizer
model_2.compile(loss='mean_squared_error', optimizer = 'adam', metrics=['mse','accuracy'])

# fit the model on training data
pX = pX_train.values
pY = py_train.values
model_2.fit(pX, pY, epochs=50, batch_size=64, shuffle=True, verbose=1)
# Out:
# Epoch 1/50
# 38/38 [==============================] - 1s 4ms/step - loss: 0.2750 - mse: 0.2750 - accuracy: 0.6208
# Epoch 2/50
# 38/38 [==============================] - 0s 4ms/step - loss: 0.
50
# 38/38 [==============================] - 0s 5ms/step - loss: 0.1495 - mse: 0.1495 - accuracy: 0.7825
# Epoch 45/50
# 38/38 [==============================] - 0s 5ms/step - loss: 0.1504 - mse: 0.1504 - accuracy: 0.7783
# Epoch 46/50
# 38/38 [==============================] - 0s 5ms/step - loss: 0.1497 - mse: 0.1497 - accuracy: 0.7779
# Epoch 47/50
# 38/38 [==============================] - 0s 4ms/step - loss: 0.1502 - mse: 0.1502 - accuracy: 0.7742
# Epoch 48/50
# 38/38 [==============================] - 0s 5ms/step - loss: 0.1525 - mse: 0.1525 - accuracy: 0.7804
# Epoch 49/50
# 38/38 [==============================] - 0s 4ms/step - loss: 0.1494 - mse: 0.1494 - accuracy: 0.7742
# Epoch 50/50
# 38/38 [==============================] - 0s 4ms/step - loss: 0.1480 - mse: 0.1480 - accuracy: 0.7779

# %% [markdown]
# ## 2.2. Bot Detection

# %% [markdown]
# ### 2.2.1. Merge dfBotAll data with labels

# %%
dfBotAll.user_screen_name = dfBotAll.user_screen_name.str.lower()

# %%
dfBotAll_train = dfBotAll.merge(trainingUserDf,
                               left_on='user_screen_name',
                               right_on='screen_name')

dfBotAll_train
# Out:
#                   user_id                 user_name user_screen_name  \
# 0     1512081815292432394                    sezgin  sezgin953116371
# 1     1425452291428077571                  Adem Koç       gogoadem61
# 2               328164303         Necmettin Balıkçı         dewil511
# 3     1343666971368431622              Night Bird⁷🦉   midnight__bird
# 4     1240932880488038400             Samed Pınarcı     samedpinarci
# ...                   ...                       ...              ...
# 2995  1286770207134973954            Hamide Arabacı         anka6054
# 2996  1598032338323214338      atamabekleyenbahceci  atamabekleyenzz
# 2997   760235343966863360                Emrah İNCİ       memrahinci
# 2998  1553973684100124672                 Murat Kkk       muratkkk18
# 2999  1392390985645281283  Münferit Fenerbahçeliler  mnferitfenerba1
#
#            user_location                                   user_description  \
# 0
# 1
# 2
# 3                          La vie est un sommeil, l’amour en est le rêve...
# 4                         Orman Mühendisi - Orman İşletme Şefi - Orman G...
# ...                  ...                                                ...
# 2995
# 2996
# 2997  Istanbul - Bayburt  Researcher | Middle East | Political Science |...
# 2998                                             Normal sıradan bir insanım
# 2999                      Fenerbahçe S.K. Kongre Üyesi Kırmızı çizgileri...
#
#       user_followers_count  user_friends_count  description_len  \
# 0                       46                 430                0
# 1                       14                 171                0
# 2                       21                  49                0
# 3                      422                 260               48
# 4                      133                 202               60
# ...                    ...                 ...              ...
# 2995                   151                  61                0
# 2996                   173                 367                0
# 2997                  5863                5905               71
# 2998                     1                  10               26
# 2999                   281                 270              156
#
#       followers_to_all_ratio  user_is_verified  user_tweet_num  \
# 0                   0.096639             False            1535
# 1                   0.075676             False             113
# 2                   0.300000             False             219
# 3                   0.618768             False           15191
# 4                   0.397015             False            3734
# ...                      ...               ...             ...
# 2995                0.712264             False            5288
# 2996                0.320370             False             311
# 2997                0.498215             False            1029
# 2998                0.090909             False              18
# 2999                0.509982             False            7165
#
#       last4_created_at  tweet_per_day  user_favorites_count  \
# 0                 2022              0                  9627
# 1                 2021              0                    74
# 2                 2011              0                    25
# 3                 2020             21                 84933
# 4                 2020              5                 15783
# ...                ...            ...                   ...
# 2995              2020              7                  5347
# 2996              2022              0                   196
# 2997              2016              0                   725
# 2998              2022              0                    38
# 2999              2021             20                  4106
#
#       user_is_translate  user_extended_profile  retweet_total_ratio  \
# 0                 False                   True             0.050251
# 1                 False                   True             0.761062
# 2                 False                  False             0.010101
# 3                 False                   True             0.085000
# 4                 False                   True             0.780000
# ...                 ...                    ...                  ...
# 2995              False                   True             0.000000
# 2996              False                   True             0.580000
# 2997              False                   True             0.040000
# 2998              False                   True             0.769231
# 2999              False                   True             0.045000
#
#       num_median_favorites  num_of_tweets      screen_name isBot
# 0                      0.0          199.0  sezgin953116371    No
# 1                      0.0          113.0       gogoadem61    No
# 2                      0.0          198.0         dewil511   Yes
# 3                      1.0          200.0   midnight__bird    No
# 4                      0.0          200.0     samedpinarci    No
# ...                    ...            ...              ...   ...
# 2995                   1.0          200.0         anka6054    No
# 2996                   0.0          200.0  atamabekleyenzz    No
# 2997                  36.0          200.0       memrahinci    No
# 2998                   0.0           13.0       muratkkk18    No
# 2999                   1.0          200.0  mnferitfenerba1    No
#
# [3000 rows x 21 columns]

# %%
trainingUserDf.isBot.value_counts()
# Out:
# No     2424
# Yes     576
# Name: isBot, dtype: int64

# %% [markdown]
# ### 2.2.2. Separate X and y values
# We use only 4 features here to create a baseline model. However, it is not enough to get good results.

# %%
X = dfBotAll_train[['description_len', 'followers_to_all_ratio', 'retweet_total_ratio', 'num_median_favorites']]
y = dfBotAll_train.isBot.apply(lambda x: 1 if x=='Yes' else 0)

# %% [markdown]
# ### 2.2.3. Train-test split

# %%
from sklearn.model_selection import train_test_split

X_train, X_valid, y_train, y_valid = train_test_split(X, y, test_size=0.20, random_state=42)

# %% [markdown]
# ### 2.2.4. Train the model

# %%
X_dfBotAll_train =X
y_dfBotAll_train = y


from sklearn.preprocessing import MinMaxScaler

msc= MinMaxScaler(feature_range=(0,1))
scaled_Xtrain= msc.fit_transform(X_dfBotAll_train)
scaled_Xtrain_df = pd.DataFrame(scaled_Xtrain,columns=X_dfBotAll_train.columns.values)
scaled_ytrain_df=y_dfBotAll_train.astype(float)

nX_train, nX_valid, ny_train, ny_valid = train_test_split(scaled_Xtrain_df, scaled_ytrain_df, test_size=0.20, random_state=42)

# %% [markdown]
# # 3. MAKE PREDICTIONS
#
# Here, you will make predictions with the models that you have trained above.

# %% [markdown]
# ## 3.1. Predictions for Tweets (Political or Not)

# %%
# read the evaluation file as follows
evaluationTweetDf = pd.read_csv('{}evaluation-round2-tweet.csv'.format(DATA_PATH), dtype={'tweet_id': str, 'isPolitical': str}, header=None, names=['tweet_id'])
evaluationTweetDf = evaluationTweetDf.dropna()
evaluationTweetDf

# merge it with the political dataframe so that you can use the make predictions based on the variables
dfPolitical_test = dfPolitical.merge(evaluationTweetDf)
evaluationTweetDf['tweet_id'] = pd.to_numeric(evaluationTweetDf['tweet_id'])

# define X as we did above in section (2.x.2. Separate X and y values)
X = dfPolitical_test[['check','is_retweet','num_mentions','num_hashtags','num_retweets','user_follower','user_following','user_verified','user_num_of_tweets','num_political_entities','total_interactions']]

X['user_verified'] = X['user_verified']*1
X_dfPolitical_test = X

msc = MinMaxScaler(feature_range=(0, 1))
scaledpt_Xtest = msc.fit_transform(X_dfPolitical_test)
scaledpt_Xtest_df = pd.DataFrame(scaledpt_Xtest, columns=X_dfPolitical_test.columns.values)

# make predictions based on these variables
predictions_political = model_1.predict(scaledpt_Xtest_df)
# Out:
#  65/157 [===========>..................] - ETA: 0s
# <ipython-input-52-4294d2cd0821>:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   X
#  '1593734099755302915': 0.559345991371779,
#  '1572285366354280448': 0.5039058026973608,
#  '1399798532069015563': 0.24036668148934554,
#  '1592569387965644813': 0.6584962725261171,
#  '1596564633573523457': 0.6611333220653989,
#  '1428460205688373262': 0.48864225939349004,
#  '1584995279870492672': 0.6656686155142229,
#  '1357845356147523591': 0.3010372744274643,
#  '1583401145937993728': 0.7332623145558586,
#  '1395674766644846597': 0.09081138520814275,
#  '1594791011028729856': 0.7797947807114481,
#  '1453764017693110281': 0.25132872455094885,
#  '1563197082164678657': 0.6914120643667176,
#  '1387834568896569346': 0.5553118286689983,
#  '1593533012519653376': 0.3891732240457859,
#  '1347636415153246208': 0.5275055694023374,
#  '1593299475476381696': 0.37270430582301906,
#  '1596428480451055617': 0.6719792676925469,
#  ...}

# %% [markdown]
# ## 3.2. Predictions for Users (Bot or Not)

# %%
evaluationUserDf = pd.read_csv('{}evaluation-round2-user.csv'.format(DATA_PATH), dtype={0: str}, header=None, names=['user_screen_name'])
evaluationUserDf = evaluationUserDf.dropna()

# merge it with the political dataframe so that you can use the make predictions based on the variables
dfBot_test = dfBotAll.merge(evaluationUserDf)

# define X as we did above in section (2.x.2. Separate X and y values)
X = dfBot_test[['user_followers_count', 'user_friends_count', 'description_len', 'followers_to_all_ratio', 'user_is_verified', 'user_tweet_num', 'tweet_per_day', 'user_favorites_count', 'user_is_translate', 'user_extended_profile', 'retweet_total_ratio']]

X['user_is_verified'] = X['user_is_verified']*1
X['user_is_translate'] = X['user_is_translate']*1
X['user_extended_profile'] = X['user_extended_profile']*1
X_dfBot_test = X

msc = MinMaxScaler(feature_range=(0, 1))
scaledt_Xtest = msc.fit_transform(X_dfBot_test)
scaledt_Xtest_df = pd.DataFrame(scaledt_Xtest, columns=X_dfBot_test.columns.values)

# make predictions based on these variables
predictions_bot = model_2.predict(scaledt_Xtest_df)
# Out:
#  34/157 [=====>........................] - ETA: 0s
# <ipython-input-45-0f892c77a0e7>:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   X['user_is_verified'] = X['user_is_verified']*1
# <ipython-input-45-0f892c77a0e7>:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   X['user_is_translate'] = X['user_is_translate']*1
# <ipython-input-45-0f892c77a0e7>:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   X['user_extended_profile'] = X['user_extended_profile']*1
# 157/157 [==============================] - 0s 2ms/step

# %%
modelPredUser = dict([(x,float(y)) for x,y in zip([*dfBot_test.user_screen_name], predictions_bot)])
#modelPredUser = {x: 0.0 if y < 0.2500 else 1.0
#           for (x,y) in modelPredUser.items()}

values = modelPredUser.values()
min_ = min(values)
max_ = max(values)
modelPredUser = {key: ((v-min_)/(max_-min_)) for (key,v) in modelPredUser.items()}

modelPredUser
# Out:
# {'nedenburdaysam': 0.33961252096982764,
#  'biologselim': 0.0720493923603477,
#  'bilgin21604923': 0.31444806639577605,
#  'denizlihabercom': 0.5378340997783233,
#  'burakerbaychp': 0.5071838126269395,
#  'mustafaarst': 0.45326639613860964,
#  'mvnez': 0.14058136797759574,
#  'farukhalit2': 0.478103299929,
#  'harlunoshi': 0.21222793301443166,
#  'tamerduran_1': 0.3066021582781926,
#  'donkisotumsu': 0.23678201773389487,
#  'enveraysevera': 0.478956191117688,
#  'gendenmukatol': 0.454695704195112,
#  '1905anason': 0.08575449648639255,
#  'dasiskein': 0.7188616264151886,
#  'ercan_bas29': 0.47342307912875853,
#  'mett_1907': 0.3861478575163155,
#  'haberinyokcokk': 0.05710981330487227,
#  'han34nesli': 0.33251247619157037,
#  'mehmetaltay64': 0.4423914700494359,
#  'nurtencam2': 0.3223372119027217,
#  'berkeduranovic': 0.32969575012718283,
#  'cagdasadim': 0.7159906637615387,
#  'yorumsuzadam87': 0.32682836405078336,
#  'twitsildiren': 0.6347560116568002,
#  'nurdiyoloji': 0.6818248461440982,
#  'merabalare': 0.4996329231383015,
#  'sevdaac72373936': 0.3488892804614941,
#  'cakan0_': 0.6215083695214767,
#  'ozlemesor': 0.33687303427578513,
#  'muratyazgan51': 0.6047639127078999,
#  'emre_caliskann': 0.5616171626321854,
#  'oguzhanonel': 0.5660662287547943,
#  'mintchocolatemx': 0.33627336965584337,
#  'mehmet07454846': 0.5511741449916491,
#  'lifegs': 0.15618612762780745,
#  'begumkarabeyx': 0.37189262497767395,
#  'mhakankocak': 0.34478944505998865,
#  'avutulan': 0.6481901257512312,
#  'imamgibiimam': 0.1528788041767857,
#  'durdane52': 0.4823936248147437,
#  'emsettinerdoan7': 0.5387220708205901,
#  'suaterce': 0.6195380184159922,
#  'ibrahimcalsskan': 0.7048112631611,
#  'uykusuz75': 0.3055831522241987,
#  'goksubayy': 0.4724810184798562,
#  'samobisus': 0.7239049922918636,
#  'haber': 0.6470966729968001,
#  'iddaaalkc': 0.0920319223727915,
#  'nnnccdd': 0.43878402644746595,
#  '_simurg1_': 0.5728675068471244,
#  'lasmananaskiss': 0.7326710361498626,
#  'kocakurt1806': 0.39853028641941035,
#  'anjelikaakbar': 0.6863654334489491,
#  'caglaademezler': 0.06820259367502891,
#  '_birgezgin_': 0.08097869410884569,
#  'alicemalakgl1': 0.11795913103969068,
#  'denizaydemirchp': 0.3221561048094896,
#  'delphinusdolfi': 0.4718145012618581,
#  'sevdesensoz': 0.19435981851663126,
#  'uortaogretim': 0.38857439370095176,
#  'furkanakinbjk': 0.8102984406294668,
#  'altinhakan': 0.5888500057237485,
#  'vedatkahyalar': 0.17916315000525096,
#  'jjuwark': 0.01856141623738145,
#  'chpfotograf': 0.8115964932003019,
#  'ibuzgan': 0.2450143309285914,
#  'emribilmaruf571': 0.29954863350129446,
#  'snurgo': 0.5927897280505393,
#  'selincivali': 0.815479578221594,
#  'tayyarturkes': 0.5179576391660294,
#  'asfer204': 0.3253517765826838,
#  'turan_3460_': 0.3966035891540638,
#  'yeb1923': 0.35377731019882314,
#  '1_legolas_1': 0.67514742541189,
#  'feyyzatemeltas': 0.03396567627404724,
#  'dr_sozdemir': 0.6778856137593965,
#  'gulden_girgin': 0.6990909932941382,
#  'n11comdestek': 0.5766539752884479,
#  'tamer71374895': 0.4353451719183518,
#  'ozgurceylanchp': 0.3820177191965998,
#  'vkooktime': 0.7557982625232689,
#  'meftuniyet': 0.5346185118592075,
#  'aygultoni': 0.6081578395474444,
#  'hbb_ciftcioglu': 0.2567470721244484,
#  'safakikiyuz': 0.10957460508646608,
#  'melihaakyol77': 0.5818721525025102,
#  'emindoganl': 0.583044485933285,
#  'binbir_surat5': 0.5780432550762716,
#  'asikkutluserkan': 0.14096360854695156,
#  'yorgun_anney': 0.6368621747093804,
#  'ozkancvs': 0.3540466068680915,
#  'bakhelebak': 0.7037615132410157,
#  'erhan26803641': 0.41006582592440866,
#  'qquazarr': 0.3233549931014929,
#  'zgrlknegzel1': 0.5337849243888297,
#  'mekinsoyer': 0.4942741325446703,
#  'primiti16830778': 0.5892795869474626,
#  'seherda20': 0.3582252494546271,
#  'alipulcu': 0.5717078139222483,
#  'onurbattal69': 0.43375873943387827,
#  'safaktun1': 0.5358306285876162,
#  'ebusasln': 0.3300222720324569,
#  'alibayr61201909': 0.27920685038988735,
#  'benigermeeyin': 0.64685552350055,
#  'cakirkeyif1903': 0.07608144427382756,
#  'mnurpol': 0.08910465006241494,
#  'umitbeyaz34': 0.6925251813698247,
#  'mkurus': 0.3825823774542761,
#  'sankisekerdir': 0.41986241397259966,
#  'barkinamaweasel': 0.06896145272826824,
#  'tubiiiissss': 0.4982438393273134,
#  'binnazatma': 0.23618447211348842,
#  'aysegul2712': 0.4745291723890882,
#  'cerrahdrmurat': 0.3105834521912427,
#  'arzuerdemdb': 0.7917073920821096,
#  'caglayankacar': 0.14575920458489766,
#  'yinemihakkli': 0.09284412999525662,
#  'alioktaydereci': 0.5683382861987405,
#  'mudiclk01': 0.30311720019849514,
#  'birsen_birgul': 0.05561358069006923,
#  'sahinsahinbay': 0.40447480278054876,
#  'ssairaoml': 0.5278121383691509,
#  'daysoldier': 0.553754865951722,
#  'ldtasdelen': 0.5953637857982006,
#  'trtradyo1': 0.3525026033685331,
#  'resmihaberler': 0.5208080242519374,
#  'erkanmuhammet61': 0.10171802235561658,
#  'emirssenol': 0.5462225942624694,
#  'eyzira': 0.532763885075166,
#  'globalkripto1': 0.5865953902181739,
#  'bulentsanverchp': 0.5308666333293738,
#  'vidacitigris': 0.5954784322470477,
#  'noluyoruya': 0.10159804166227454,
#  'bisakinol_1881': 0.39401164852015075,
#  'sevalkayan01': 0.5716095315391768,
#  'scan_monitor': 0.4212132823006387,
#  'hasankocatepe26': 0.30558697377249355,
#  'bekiray23': 0.062214745763783094,
#  'valisu31': 0.5056342237875654,
#  'frat22880933': 0.3589098455357126,
#  'haber_ortami': 0.8367206255404215,
#  'nkomakhos': 0.04901084397399769,
#  'alipeker1903': 0.13239091421013582,
#  'pyrzca': 0.5440069781471865,
#  'turkan__ay': 0.4142028969246849,
#  'abarrjinn': 0.29897873286326493,
#  'sehrivan': 0.5570050437823274,
#  'klozomenai345': 0.46777551666781764,
#  'alisahin343434': 0.40892744548040794,
#  'onurkirac01': 0.589125941108324,
#  'kingofthebjk': 0.5112514098389828,
#  '__ebedmuddet__': 0.5348632869269169,
#  'aydoganali68': 0.5672441475253845,
#  'endersarilacvrt': 0.41728125206464656,
#  'ysmntrkci': 0.1884257011763338,
#  'bosnakizmm': 0.3130074896712246,
#  'bilalbatmaz4': 0.6166064989201309,
#  'semihates43': 0.19615183070168699,
#  'besiktaslicmali': 0.4738385500203069,
#  'ilkmp3': 0.7652450319198496,
#  'babai1235': 0.4133063763929635,
#  'ebruli_1907': 0.6472411079246638,
#  'hamitpicak46': 0.31273481240154155,
#  'krtl_88': 0.33227730398880717,
#  'captzulu737': 0.3873977487797931,
#  'ahmetbeyefendi': 0.5775756543464441,
#  'aliefeuygun': 0.30315600361195105,
#  'ugur_tarhan': 0.2856014765482727,
#  'dvdkaktuna': 0.07021800261095039,
#  'vedatcoksert': 0.3205997792663906,
#  'ludwigplanckk': 0.1441006281278056,
#  '34feyzu': 0.08460269469128884,
#  'yetkingdom': 0.7218056884285305,
#  'firatyurdakul': 0.02990407472831915,
#  'rserkant': 0.0505395750599977,
#  'serkanyardim': 0.16976203096282122,
#  'ay47729837': 0.48656802940220867,
#  'tbatmaz2': 0.46636320960180666,
#  'yavuzz65': 0.09840033662941057,
#  'wlato_66': 0.3121303708462312,
#  'starlightd0': 0.41862817635886845,
#  'alfredofoot': 0.43448914510029374,
#  'alidursuner': 0.41933067982331024,
#  'yagclut': 0.34320840193849506,
#  'gezsed': 0.5744274824587872,
#  'iyusufturanli': 0.8001129365509562,
#  'tvnet': 0.5166036352086202,
#  'muzafferburann': 0.05628784052414396,
#  'utikitiki': 0.17281841220008715,
#  'bugan_hac': 0.14555423731192685,
#  'ercanyentek23': 0.35507183518661684,
#  'engltunademirb1': 0.6732614423341469,
#  'zaferisik016': 0.711636842381049,
#  'xxemineww': 0.33492544098033883,
#  'dumendenhaydar': 0.7593556340437339,
#  'ykiranoglu': 0.46934881870430356,
#  'furkicanab': 0.05915795726215559,
#  'ylmzhasann1': 0.36737663276569543,
#  'hsnkaratas1907': 0.20727463074228358,
#  'ouzhane77084805': 0.3875449028862513,
#  'kvseryyla': 0.36005013675386077,
#  'waspazy': 0.2464006833124328,
#  'mehmetg60069663': 0.14824477879126927,
#  'eneskaanylmz': 0.6077304140689223,
#  'borusanlojistik': 0.851737448559449,
#  'oguzhnu': 0.3126724917678093,
#  'volkanipek32': 0.023758480009542112,
#  'turizmgazete': 0.3785547350195981,
#  'mer06666': 0.353212872415087,
#  'su_pinari': 0.664503923468498,
#  'denisinbiri': 0.6964201229896727,
#  'timbooth75': 0.7484131694375791,
#  'pillibebek413': 0.7804486208632383,
#  'hknsaribal': 0.24494984230111494,
#  'mustafhaaaa': 0.4560040210527136,
#  'ossurukboceki': 0.5688320498361253,
#  'yunusbozkuurt': 0.3982715969963708,
#  'aksakal_memet': 0.592444710831402,
#  'iyiozgurozyurt': 0.40500729634007626,
#  'isa_ozguller': 0.6165167415294096,
#  'baraan56': 0.662114377911588,
#  'aftiel86': 0.3121889189258774,
#  'mygazeteantalya': 0.8265962662346292,
#  'cemile_cetiner': 0.33970303777078703,
#  'karantinatv': 0.1278433697276199,
#  'alidavutoglu': 0.7959423535117861,
#  'hatembenarda17': 0.07527227735445284,
#  'ekmek___teknesi': 0.3955930346011067,
#  'gokcegokcen_': 0.5614960489477624,
#  'halilibrahimy_': 0.4492159468996844,
#  'aaltuntas70': 0.47275783576019204,
#  'umayy1907': 0.30895211651430404,
#  'siyaaydin': 0.07768920761200486,
#  '1979hisarli': 0.5461486130070169,
#  'gokhangokmen63': 0.733125212466449,
#  'samueljsdv': 0.4018472678538633,
#  'chpuskgenclik': 0.4053291392983995,
#  'kksalseyfullah': 0.1292339478619797,
#  'miirac0909': 0.5909986957496617,
#  'ozleemcelk': 0.08064285105532669,
#  'ahmetayhan99': 0.3902914447463767,
#  'osmanakgul29': 0.44992116954272066,
#  'yusufberk06': 0.5224080771264877,
#  'hibakkus': 0.49889340454902903,
#  'aliyecdaroglu': 0.702282280085635,
#  'tallman93409915': 0.277462828032458,
#  'isimsizisim123': 0.40656834982433493,
#  'uzunnman': 0.49651365783390083,
#  'emotivasyon': 0.6917708665294616,
#  'alimutum1964': 0.6586214827700473,
#  'asliarslaan': 0.8151694448792,
#  'mustafa_destici': 0.8208055426952562,
#  'lifeis35': 0.31948190289881834,
#  'savunmasanayist': 0.6300236610182794,
#  'canernevermind': 0.4155341185749515,
#  'azkalsin': 0.45677795807374466,
#  'borahan1903': 0.06265036858588334,
#  'yalcingg': 0.054582324552779025,
#  'gundemedairhs': 0.6620267762660588,
#  'emirgs19_05': 0.3872887121678661,
#  'birkomikpanda': 0.5376657556765119,
#  'davut_sandikci': 0.7765325137451415,
#  'iamcansun': 0.6351562943435868,
#  'enastaenistera': 0.72294098223737,
#  'mussy_33': 0.3863544171010759,
#  'mminbicil2': 0.40055808323484066,
#  'gokhanmirall': 0.657437684694388,
#  'ayemyasin': 0.6118580781810881,
#  'yucehuzunlu_': 0.29983517613209876,
#  'almaz6060': 0.0910032644596425,
#  'kardii2424': 0.07637332114912683,
#  'corumtweet': 0.6301880855833781,
#  'nurkanmaz2': 0.3373245649050905,
#  'imeratarot': 0.5777969121938772,
#  'erenicooo34': 0.5271398398345015,
#  'huseyin14330438': 0.5717188866134617,
#  'msen5885': 0.06811257294043473,
#  'lebron2_king': 0.28974979171949367,
#  'nesrinaras141': 0.06841047916556788,
#  'krkharman': 0.08607272612180876,
#  'ysametiscii': 0.3793796260178945,
#  'muallarenksiz': 0.5438114912536396,
#  'avmehmetozkan1': 0.5485367867260774,
#  'aykutsafakkayaa': 0.3640875290361117,
#  'hatiec1209': 0.8048340185214278,
#  'nurhayatesmaa': 0.04651506213041372,
#  'murathanmhp': 0.3268599163213208,
#  'haber_logg': 0.6601540216247209,
#  '8lampardd': 0.038420202188811384,
#  'kaan_blky': 0.01902727461065466,
#  'mebucretli': 0.35822032553663175,
#  'seheruygen': 0.36717901462406094,
#  'kurdgirll': 0.6362847289631789,
#  'guclu_umutsuz': 0.08297514075485035,
#  'izmilli19': 0.18393931371508854,
#  'isimsiz676767': 0.31507073379680056,
#  'drmetinilhan40': 0.3559459163706579,
#  'kaanboz10993308': 0.3567935161847837,
#  'tekirdaghatice': 0.3505336975922114,
#  'arifklarslan1': 0.36551921331174614,
#  'm_songulalp': 0.11678178795105508,
#  'almilapars2': 0.0749433042076643,
#  'fetihkurun': 0.5723681578699239,
#  'yasinucantr': 0.11849521954929688,
#  '__lluvia_': 0.6690954647506142,
#  'alimbilge4': 0.5350307491329679,
#  'iyiamanedenyani': 0.664619157847852,
#  'kuyuma': 0.8324068814228193,
#  'cengiz1bey': 0.4395404725359165,
#  'brcukocaa': 0.42100500791856654,
#  'mustafa_yalcin2': 0.09046380147389768,
#  'hanifekrcdemir': 0.45834121629740426,
#  'mustafa55450232': 0.3398918614519223,
#  'osman_gencer1': 0.4309328269553203,
#  'massimomeltem': 0.06070644220076009,
#  'aryaates10': 0.35158229614838643,
#  '68hanak75': 0.2763114396259919,
#  'senidesavunurum': 0.6305991469961246,
#  'camideyizbiz': 0.6994906880504178,
#  'emrahadakli': 0.682374659156475,
#  'adige_turan': 0.36572565041098426,
#  'tknnnur': 0.07944581841898579,
#  'kemaleren50': 0.06807053437812177,
#  'knstntndeluu': 0.41437476860953776,
#  'dilekkat1': 0.3650935761218492,
#  'rdvntrkylmz': 0.09894740596608852,
#  'sporturkiyetv': 0.6373427099103599,
#  'samsun_1453': 0.4860131209921053,
#  'kemalak72155735': 0.06698997169384077,
#  'srkncansu': 0.3867931112476471,
#  'feydem003': 0.3488613292653115,
#  'bkrhly0803': 0.6453897147584104,
#  'trksever11': 0.5537325245924595,
#  'tetecrystal': 0.4200461422560084,
#  'erdemyl86277666': 0.5517152370348402,
#  'osanmaz_kaya': 0.6579220414436624,
#  'kwmitchi': 0.09067911264922442,
#  'joker39831854': 0.34956633143440763,
#  'muratdu68243139': 0.6027972851622925,
#  'ibrahim_0634': 0.2142063926614906,
#  'j_j_o_10': 0.6089581109557641,
#  'baliskonuz': 0.49928966971068506,
#  'ozantur33802030': 0.050083510935299204,
#  'oncesiwesonrasi': 0.35673648692561366,
#  'mavisciik': 0.05189533056037543,
#  'otodidakttweet': 0.3129043323643667,
#  'akilfikirparti': 0.3485730718371954,
#  'laylabesiroglu': 0.49950965370868644,
#  'ansuh1995': 0.34670531460516635,
#  'sleyman59570757': 0.3528486004718485,
#  'kocagolali': 0.07884924655848141,
#  'mhmettedebiyat': 0.6163976856017607,
#  'mustafa043yedek': 0.3401331579307992,
#  'anteplimamato': 0.07487363291152667,
#  'tbuyukcebeci': 0.15080913568556653,
#  'karizma7583_': 0.093310267023093,
#  'spinazzola01': 0.525914102716016,
#  '1mirzabey': 0.5959094832970291,
#  'hln_sbs94': 0.6314213678100355,
#  'chpyemevzu': 0.35792540489610397,
#  'stajzedenur': 0.37477169617289824,
#  'ahmetarici3': 0.3520911500021153,
#  'smeyye54030601': 0.3529979103234987,
#  'aylinmustafa411': 0.38247510463386986,
#  'mdogan80': 0.35987042599558255,
#  'onediocom': 0.8109466340133329,
#  'hasanlal18': 0.423491978459892,
#  'huseyin120322': 0.3347502131921758,
#  '_albayrak28_': 0.4253309760912915,
#  'aynurr82444477': 0.33168753619906505,
#  'dinocanzygl': 0.44199993282893957,
#  'yuzlasma': 0.5900452684442925,
#  'vethekbusra': 0.4946443327871867,
#  'hayriyealtan1': 0.41254973432767733,
#  'arifedemir0651': 0.053410804885192974,
#  'yilmaz_dagdelen': 0.3005179839245591,
#  'cybermigren': 0.34776444691625674,
#  'ayyldz38106604': 0.11456719458988307,
#  'hiciiknoktasi': 0.5328541324079764,
#  'hfzfehmitufan': 0.0890925638035047,
#  'feyzanurduran1': 0.5510273583417576,
#  'tmollaveisoglu': 0.36009935143670985,
#  'inmerveout': 0.656066336787025,
#  'gmtn73': 0.336030211397028,
#  'nesfrit1': 0.3574256639652321,
#  'feedanhsynli': 0.7687518414167205,
#  'cuvalogluberkay': 0.44423477917121934,
#  'ynshss7': 0.04335220116649822,
#  'turan5801': 0.08078254885561655,
#  'oxlade25': 0.07116723019397468,
#  'dorarafa': 0.34339707863700364,
#  'aydinvaliligi': 0.7055909570016778,
#  'sevgierol759': 0.3097272538934534,
#  'deplasmancom': 0.07255128903641155,
#  'hudeydankayaalp': 0.2109071348821105,
#  'kellecimehmet58': 0.09869964225163567,
#  'emir_k16': 0.5320492555440193,
#  'asiruhumbjk': 0.5364298277625734,
#  'merym2y': 0.04764685744652325,
#  'mrtkaan5': 0.2119077068650024,
#  'abbas0784': 0.36615412926499796,
#  'gracenewbie': 0.5486535889201164,
#  'esra_dmr1': 0.39604037622555033,
#  'f_ratdemirci': 0.3403564245407975,
#  'akbulutcave': 0.09381242091875361,
#  'meyaschoice': 0.420184746873012,
#  'lahuzac': 0.3092336127415907,
#  'supertolkstolk': 0.8407983155595,
#  'bugraa_hann': 0.08246102002366372,
#  'ishak5334': 0.5404086474680736,
#  'blueberyboi': 0.41147796151068844,
#  'malefiziii': 0.5879675220328795,
#  '81_karacahil': 0.23699684509140861,
#  'dzj2': 0.18151448007921187,
#  'ertugrulbaloglu': 0.11371983362252573,
#  'tennure06': 0.7397800958625591,
#  'hic23817447': 0.11495311584918319,
#  'fadimegl_': 0.03588197451855289,
#  'karital1': 0.06063492520090871,
#  'byvanir': 0.6761434776790101,
#  'nejla188136991': 0.3382847289141847,
#  'somewhere9s': 0.7026432694168766,
#  'laizlafernandes': 0.30060098011445097,
#  'izim62': 0.6387372810727459,
#  'kayanadnah': 0.3482315332068907,
#  'aleynaksever': 0.6204790011922986,
#  'hayri8383': 0.34605349564984095,
#  'demirness02': 0.365963223329984,
#  'mrynr4': 0.31527675444526293,
#  'minikbelanzz': 0.2658480893887583,
#  'tukul46': 0.10638874440360586,
#  'ccbiazin': 0.6463439259711222,
#  'behcetsagmak': 0.40888758869146047,
#  'ba_team76': 0.33980923271859725,
#  'yektaorkuncelik': 0.36109187612078847,
#  'ayhaneroglu14': 0.12897023040825087,
#  'tozlumektubat': 0.43675916928457015,
#  'ensdndr1': 0.35200634102649386,
#  'maynameserpil': 0.5502188559063413,
#  'erbasdeniz': 0.34829488271901005,
#  'marti141216': 0.22561938540145524,
#  'serdaraydinnn': 0.31497223093978904,
#  'papatya84595001': 0.33338339724913685,
#  'ndermaden': 0.360447381799695,
#  'mihri3458': 0.1984569469880945,
#  'merveko2699': 0.32352292075252853,
#  'cazhareketi': 0.19417382425106045,
#  'osmanaydin1818': 0.3355151597758721,
#  'hazalkilinc_': 0.4227988328893519,
#  '1shuuu2': 0.35101433078160876,
#  'temoootemooo1': 0.5543468139837605,
#  'purpose_less_1': 0.5116169066374439,
#  'atamabeklyntdss': 0.3505202241847615,
#  'yakagayakbe': 0.6487930484860654,
#  'mihrimahgundogd': 0.3539088841468483,
#  'ezgii22e': 0.5789554292577395,
#  'abdullahdmr5234': 0.552027036180337,
#  'fenci0101': 0.5795453195330038,
#  'yilmaz19er55': 0.3520469082314705,
#  'muhdsumar': 0.5060056978795134,
#  'radyolojitgt11': 0.07635605375262447,
#  'ersin94669386': 0.16811762608065609,
#  'agresifiimmmben': 0.33357883514847486,
#  '100binatamahak': 0.3617201043645242,
#  'kuzenraven': 0.3025496757795977,
#  'rsceran': 0.09352520155543875,
#  'herkann': 0.1680738130093392,
#  '_emel_iskender_': 0.09296262248950306,
#  'arva2k2e': 0.08659398775894389,
#  'turanordus': 0.39601338041644146,
#  'mehmetcalik1903': 0.34079264447981883,
#  'emreakan4': 0.2770135511367624,
#  'iyi_psikoloji': 0.10113941299695346,
#  'kurak_yahya': 0.32210350952622574,
#  'ergin_ilker': 0.1359141735126479,
#  'sir_gala': 0.4154873291054434,
#  'onder_1881': 0.40805049813514566,
#  'aglamicamaglami': 0.5736381857532631,
#  'bekirgz69888824': 0.5427244077463665,
#  'c_keper': 0.5274422320918879,
#  'barisustunbas34': 0.06339816260325437,
#  'cifri77': 0.5005369642810904,
#  'magdurbiyolog94': 0.08813130967326227,
#  'phoenixsnm': 0.4488251200952173,
#  'bigumigu': 0.7096493433024463,
#  'baran282828': 0.566043201476607,
#  'tayfun1981': 0.10801401704719203,
#  'aysun_becek': 0.3917171272314198,
#  'ahmetckarali': 0.7960302491225688,
#  '123ciklet': 0.3972536933120774,
#  'akkadinbeykoz': 0.0942104682447587,
#  'farukztrk51': 0.08210129229330158,
#  'gazetemuz': 0.369864901653557,
#  'tevfikozgul': 0.08753286378426713,
#  'oyablsl': 0.13799966100906855,
#  'atam02': 0.5039322629584845,
#  'jamesblacklol': 0.6190549355161494,
#  'yyasemincetin_': 0.6571320588192135,
#  'cananyslyrt98': 0.0992654947431541,
#  'ironyofsilence': 0.4967367774612725,
#  'y35936059': 0.344836626483168,
#  'sungurogiu': 0.26248179528303844,
#  'ilhan29914305': 0.34313067262606095,
#  'tbugradayi': 0.33384602506676014,
#  'muammerelk4': 0.06857523137943856,
#  'pelagia98797339': 0.2743355521749007,
#  'sedefbostan1': 0.3515327140089705,
#  'nesimsek': 0.10005263570348616,
#  'yunuserkul9': 0.3436366358214642,
#  'btcturkdestek': 0.869216230576154,
#  'ahmetkurolu1': 0.37179221134651497,
#  'racigalioglu1': 0.07399157179570953,
#  'g_durdagi': 0.09431223840307687,
#  'sofuatar1': 0.35281579884898395,
#  'duygu44655629': 0.32315014831404437,
#  'nurse03030303': 0.38846131506678977,
#  'alican69969774': 0.41971121784390647,
#  'oyumchpye': 0.754024672160763,
#  'eliscilik': 0.31069439957731715,
#  'akgulhasan62': 0.3369680585439641,
#  'dijitalgastecom': 0.632766650798259,
#  'cevahir_tolga': 0.3437386172673083,
#  'ceredipity': 0.5562934518921331,
#  'aliyletivitce': 0.6515155586867211,
#  'erolylmz020': 0.4190596193625212,
#  'baharmtumer': 0.08276488210731736,
#  'cumhuriyetgzt': 0.8628670710436361,
#  'ihsanozkes': 0.4272185269837198,
#  'emircan643': 0.4998325255453968,
#  'dejawu1234': 0.33867009286435845,
#  'toprak06233810': 0.08948900044489191,
#  'ommerakk': 0.38477785694969746,
#  'seyfullahaslan': 0.6247975467423739,
#  'mucellapakdemir': 0.32457120084634555,
#  'refikakart': 0.10602353544612203,
#  'merenwen__': 0.48963310711155594,
#  'istinye_yokusu': 0.7376567848368607,
#  'hakkitaruz': 0.37666740460110987,
#  'bbpbyrmpsresmi': 0.39895232253495255,
#  'santiagonowcast': 0.4363404647752338,
#  'tcnuriokutan': 0.38246829443883146,
#  'bilalhotmailco6': 0.4217365404517869,
#  'kemalaydomu11': 0.3107262703102125,
#  'miyy_lykia': 0.6579271368413889,
#  'mehmeta17853051': 0.36203932613267076,
#  'constantinapolx': 0.28557308440421,
#  'noyanmuharrem': 0.6189397011367955,
#  'mhmtkoyuncu197': 0.1143320407599482,
#  'altanbostanci': 0.24300772410851423,
#  'serkanny58': 0.5941087501427875,
#  'bharfiyim': 0.07233727467655186,
#  'turgut10666': 0.07937146970696637,
#  'osman5138': 0.564059719923135,
#  'nebi_nuh': 0.11360570161287221,
#  '_forever_1903': 0.42450613408720395,
#  'akkadinavcilar': 0.21813559348191824,
#  'rebercn': 0.31835643242886513,
#  '1453devam66': 0.43533245792113995,
#  'sevgiorc': 0.07376724262380549,
#  'adilagras1': 0.3926170038664515,
#  'wanhaber': 0.7588426646764566,
#  'metehannn_8': 0.34654988047740254,
#  'nineteesgurl': 0.4274630570803846,
#  'karslan17': 0.5227789632879288,
#  'yuksekova_m': 0.37797341873089274,
#  'ahaistebu': 0.6951255000134612,
#  'avhaticeyldz': 0.5620021591257924,
#  'a82317335aslan': 0.34994723691157065,
#  'kyaegunn': 0.20445964397231228,
#  'rabiacnk66': 0.3640966419589688,
#  'borsaninizi': 0.6771802931279425,
#  'epiphanlarity': 0.38065991818800016,
#  'huseyin_agars': 0.39128151972000985,
#  'lapemaia': 0.661438649782315,
#  'insaneautor': 0.4348039083954296,
#  'baweraunnehir': 0.5270507683627049,
#  'zekikar46878782': 0.32293430432669573,
#  'foraorg': 0.07497685911649087,
#  'levent28939983': 0.39962182839969407,
#  'muslumbaba25': 0.322022081151019,
#  'dniigeria': 0.41264799221364434,
#  'ahmetdoan011': 0.3815452190458814,
#  'kerem84242180': 0.3567268350664586,
#  'kalyoncu_serhat': 0.3907452781035008,
#  'fenersonhaber': 0.21810057487110052,
#  'ozlemsvk1907': 0.49181001780180084,
#  'znur26821776': 0.3499267083380378,
#  'serseriyimsenle': 0.03517010397379535,
#  'nisebinciyager': 0.5701598908859772,
#  'noyanayra': 0.11609394600362935,
#  'brahim61307090': 0.31282476576909846,
#  'yildirimsamii': 0.3130907798263699,
#  'dipsiz1kuyu7': 0.3559110569910192,
#  'omerremektar': 0.6406288494903046,
#  'presserwatch': 0.8224658584467646,
#  'kronikvaka_01': 0.41119832706334025,
#  'sevda78899': 0.4218336959680534,
#  'serhatkozturks': 0.15198272459294448,
#  'koksal87889937': 0.8609050489536662,
#  'alikara16952218': 0.3973029814862398,
#  'gokhantepe_': 0.3489342326481681,
#  'aysen_yldrm_': 0.32831695510006564,
#  'busraurr': 0.4252469510230126,
#  'fulyasimsekcakr': 0.37037137928815383,
#  'cuma06235351': 0.5573426138817105,
#  'fatihsu145323': 0.5156763708108083,
#  'timucin3406': 0.36875653016251303,
#  'darkes_48': 0.6181426633462638,
#  'ebeamaatanamadi': 0.349530075719815,
#  'adalethak6': 0.13016131024820932,
#  'prince__raji': 0.4309675638494368,
#  'kddrummondnfl': 0.701985081214393,
#  'furkanblenterd1': 0.31322186383230594,
#  'ferhanxyz': 0.5889236930139476,
#  'zorunlucografya': 0.32084822889976816,
#  'ddurust2': 0.1089995600565011,
#  'enver_ozonay': 0.3786596561179767,
#  'yazdikanka': 0.5193002764669717,
#  'sait0901': 0.3442091086554615,
#  'jonturkei': 0.32012992480295327,
#  'irfan_girgin_': 0.3393308777599142,
#  'ahmetsenal1': 0.03983122162576944,
#  'zpyenimahalle': 0.40805819022594436,
#  'hunilisaphiens': 0.34893366921476565,
#  'promo_togo': 0.41044276287065007,
#  'memetuar18': 0.32489328877571333,
#  'gkhan989793831': 0.5838052680092239,
#  'bbisekreter1': 0.3467829704262871,
#  'tvvjce': 0.3791385745100622,
#  '_saituk_': 0.224168201430675,
#  'kemalolu6': 0.05869326862562008,
#  'serkanksoz': 0.5302450927951542,
#  'yedinchss': 0.07616539278865508,
#  'eersoyol': 0.507199098820119,
#  'adelante_d': 0.5885231163619076,
#  'ressam51': 0.5643193892303526,
#  'maviasi17': 0.6349234738628512,
#  'lee_wonho_shin': 0.31913005098753827,
#  'seymaac00__': 0.6017596858060176,
#  '500ml26664613': 0.42970535054241854,
#  'kenan_kiran': 0.6312690938087464,
#  'ozelsakura': 0.4713460676304791,
#  '1996staj': 0.3427061378058644,
#  'acitangerekler2': 0.6324352539691984,
#  'dts_textile': 0.5649034981889658,
#  'mel75801': 0.12607040404127753,
#  'mecnun7979': 0.3462506238493863,
#  'titoforever__': 0.6159362581422557,
#  'noavasblog': 0.241033992402615,
#  'mustafabaygin': 0.24318846374517955,
#  'smr_plt_': 0.5716880202618491,
#  'tirabistan': 0.7168324822590132,
#  'furkan11572471': 0.3731778655628794,
#  'defnecaglaltd': 0.5577836597503093,
#  'bekirgonenn': 0.31923651540349757,
#  'sananelantospik': 0.5925349581642124,
#  'cagricantopcu': 0.4437686482676591,
#  'jossalove24': 0.7241710308462395,
#  'ruyamca_xyz': 0.6657757151433579,
#  'jonginimio': 0.39677087988038356,
#  'iyipekipekiyi': 0.09856306477002572,
#  'jawarecep2071': 0.47789331074961605,
#  'plushurriyet': 0.2737443880502047,
#  'smalylmaz12': 0.054285271898629216,
#  'alperrustem': 0.5701489161831816,
#  'bernaa__21': 0.37271687905125456,
#  'ggokcayoglu': 0.47165693588600677,
#  '1cet1_cet': 0.07285471629646112,
#  'hseyins27723625': 0.3690936593140159,
#  'demetswife': 0.46316677841837434,
#  'mustafa74628820': 0.5095589538864301,
#  'efe25454822': 0.35456545554043783,
#  'mcuyan94': 0.07592820569905047,
#  'merve_trh93': 0.4415678529005711,
#  'tumerkara01': 0.12305953842408804,
#  'yenisolukcom': 0.3541722770139431,
#  'voyageofdamned': 0.339007956928995,
#  'tosbiikkk1': 0.09522308055449,
#  'gu_kisver54': 0.08350550306629032,
#  'hakonlothbrok': 0.47291285343718015,
#  'kemeroglu_ctn': 0.35500385572175563,
#  'fadimenurkrcbn': 0.4060311038265432,
#  'kucukdunyatr': 0.5398885249462956,
#  'ekobey37': 0.1322251055586355,
#  'gayrimenkul_cb_': 0.5254861872954047,
#  'imparator2569': 0.3010113556082728,
#  'ismailttpaloglu': 0.3461737274385036,
#  'busraa_errenn': 0.0481373553136706,
#  'zerdali06': 0.32959999094587017,
#  'gizooo_1299': 0.05644252519361838,
#  'edizyil47765465': 0.5612730273088086,
#  'xivagil': 0.5564687531716095,
#  'kaptanhindostan': 0.4057418910113534,
#  'hardtoliveya': 0.3241313798329694,
#  'm_eminozdemir33': 0.26043912872520425,
#  'tarihogretmeni6': 0.34240185927143507,
#  'gnayuyar1': 0.12646210049295278,
#  'kazimkarabek5': 0.6052793317856227,
#  'tylerdiyebiri': 0.3542259991640118,
#  'ayse_sahin42': 0.1105258337767105,
#  'ahfalandunya': 0.8137477309250786,
#  'bartinnash': 0.1317990029237539,
#  'helyalina': 0.17111571645787255,
#  'feyselsimsek': 0.4928116554087365,
#  'kamudaii1': 0.5186000512332443,
#  'cobanozan': 0.4355326237616377,
#  'denizzzz1234': 0.6459388418518626,
#  'muratdlgc1995': 0.3184274005404698,
#  'nrdnkle': 0.7506348608347667,
#  'vefakarguvenlik': 0.36256246179829665,
#  'ayaz043043': 0.4129985457783883,
#  'suskigm': 0.6535036456958305,
#  'cetinkaya1978': 0.41521933078271117,
#  'k971689': 0.3555181724297779,
#  'bibercizehra': 0.17010162207332175,
#  'matrixci2': 0.5938704423106541,
#  'haber3com': 0.6794638152167732,
#  'blueandpurple61': 0.4038781268073504,
#  'msdegngr07': 0.37533439466221813,
#  'egonfrr': 0.3915417279635256,
#  'krgzeem': 0.07847125317461039,
#  'ozankimkio': 0.5651863907512064,
#  'acikistihbarat': 0.5429666351152127,
#  'cabbarhalletsin': 0.20471790469602388,
#  'meribasgeri': 0.8218564684763543,
#  'genclikhasan': 0.3623858621722842,
#  'edebiyatci_96': 0.35484072950319306,
#  'du35518218duman': 0.0850301477290535,
#  'yasemin_busrayy': 0.29631677950482094,
#  'ttaynaralimaa': 0.3220549562651969,
#  '2020kpss202020': 0.07528993670462648,
#  'kamil_kebabc': 0.3378793018354627,
#  'mrscelikbilek': 0.36770557988431046,
#  'anadoluatesi36': 0.43494150863115055,
#  'tomrishatun0703': 0.3657713375107919,
#  'anasonx': 0.43325743068832134,
#  'krklm': 0.16983939281868854,
#  'mnreelk1': 0.113821447611803,
#  'mimarastr': 0.3121051143315386,
#  'krml966': 0.4530189998807236,
#  'arami_omer': 0.48706051919016197,
#  'ifsaci_abi33': 0.07554169497817442,
#  'sfrsml': 0.3532862902371371,
#  'nesrin_kr72': 0.3995005677326443,
#  'denizsuyu61': 0.10572441967645645,
#  'ercan_cumali': 0.10614242601831585,
#  'alban_idris': 0.31999546019660247,
#  'srkncmk': 0.3339979806056914,
#  'lacasadeads': 0.6259185342422119,
#  'avmelihdemirer': 0.7513374377905219,
#  'koinsaati': 0.7803134948350673,
#  'iyisaplayan': 0.34978288583778544,
#  'ornek01h': 0.12406928457259817,
#  'okacmaz72': 0.7404720900691899,
#  'gercekmuhabir': 0.3374905082906653,
#  'bhttnkocak90': 0.06627765407692693,
#  'thatsmyrain': 0.4682063717409634,
#  'baydno': 0.7671003446228157,
#  'halimsldk': 0.1186219798162967,
#  'burcu21414482': 0.5672885362786562,
#  'uiltimo': 0.6146694638767045,
#  'ehmania1': 0.6019022589539428,
#  'aysesusarac': 0.6707154092739815,
#  'sevil_atasoy': 0.5880916733582549,
#  'tjvudjnkfytcu': 0.6087155896216645,
#  'da_lalis': 0.4329209139644299,
#  'livelyforbes': 0.0508758713099491,
#  'harun_karacan': 0.5171810809548216,
#  'milletvekilic': 0.3975976081615141,
#  'llamahwang14': 0.6334510019083,
#  'fezzaloji': 0.19264971240031914,
#  'murat11649766': 0.33269282387456445,
#  'arsendef': 0.6853336154093255,
#  'bezrhn': 0.48731068362085134,
#  'resulankaya10': 0.41400846340662956,
#  'nureyluel': 0.6182497646869389,
#  'gllisee': 0.6509074425657424,
#  'ah_pendik': 0.6310987899385787,
#  'mutivedat54': 0.3389181260469603,
#  'pekk69864980': 0.3408252746229522,
#  'hanfenndii': 0.3237636782951074,
#  'gumit841': 0.5817950356176875,
#  'oha_yanii': 0.4256907405673103,
#  'genclikplatfrm': 0.6696788877903026,
#  'kifayetnc': 0.3786801601944051,
#  'kunwakul': 0.16331474827841086,
#  'betuldikennn01': 0.3388479418426982,
#  'erdemdursun1953': 0.3809744365120915,
#  'bahadirsabir': 0.25366293566783554,
#  'with_hoope': 0.3496229932370109,
#  'mouyanal': 0.44628077733525934,
#  'yusufelmas': 0.45047744979067345,
#  'berenkarabey': 0.3791298535408764,
#  'lezbottann': 0.5441374987197201,
#  'irmkcy_11': 0.06648685169362324,
#  '10sefa1903': 0.2724302898759518,
#  'maryandgringo': 0.625801634059755,
#  'suheda_ks': 0.2379993890912091,
#  'hakan_memur1': 0.5533560530912026,
#  'gizemlax': 0.714755421766525,
#  'kayaufk2': 0.3956026619631573,
#  'nurhannsd6259': 0.36072182286089877,
#  'eskileriattim': 0.6583407459529987,
#  '__benbilmem__': 0.4602486098444407,
#  'ssbuse': 0.4269129011085454,
#  'englvural9': 0.36754813699398137,
#  '10zekeriya': 0.6126214079558903,
#  'gotham_knightt': 0.5725049497011978,
#  'fzt1986': 0.5052639255566311,
#  'mazlumunah4': 0.08747973568898143,
#  'kartal28asil': 0.2097097409134789,
#  'mdnhakann': 0.1772784530254916,
#  'sekipdadas': 0.34022926007157417,
#  'selim09219758': 0.6479922871356567,
#  'isaozguness': 0.08804292412039043,
#  'salimkaugama': 0.118289278516424,
#  'ismaillsahiner': 0.09083185209549824,
#  'klavuzukargaa': 0.3373585913831778,
#  '1071fatihan': 0.5803306967018151,
#  'juniorcivciv': 0.41622758260784953,
#  'madran_sena': 0.5461179426322399,
#  'eyupiskuran': 0.34642844833062153,
#  'baristurkdogdu': 0.30239718130436843,
#  '1923zetazeus': 0.13393190456584628,
#  'hypex_emre': 0.39352111850055377,
#  'delico93742981': 0.02226461595852601,
#  'skender33766338': 0.35286601791311567,
#  'ferit3481': 0.4358787188533709,
#  'kadirseymen41': 0.27051375890895385,
#  'muslusukran': 0.11948675822492119,
#  'beytbaba': 0.3150492253390895,
#  'fevzigenc12': 0.503585187982573,
#  'mehmet_kolay53': 0.3798210638401646,
#  'semihasattler': 0.38513360390058576,
#  'mehmetbir4284': 0.5624925911569716,
#  'mahmuttknmz': 0.4275309140597236,
#  'elfidamm21': 0.6196518809574968,
#  'alibabacan': 0.5832249805989057,
#  'vtimidir': 0.4593065981897473,
#  'ucmagayolculuk': 0.5698767043584831,
#  'anbaksi': 0.3558254396109507,
#  'mujdatgokce': 0.5169171981456377,
#  'habibet12': 0.5929068242098318,
#  'malsfbittik': 0.7790625746932025,
#  'tuncayopcin': 0.37988279654338997,
#  'beyhanuar10': 0.2242909074268876,
#  'frkncetin1': 0.41061399763078704,
#  'mahmuta96573806': 0.5142264361923553,
#  'bilgibakanligi': 0.69291429337698,
#  'yesesm123456': 0.7041586602984321,
#  'enerjiyihisset': 0.47219714603343743,
#  'aarmaugruna1905': 0.36293251505818636,
#  'hasanemrekaya14': 0.35345705955228945,
#  'ekg7154': 0.06534637215398459,
#  ...}

# %% [markdown]
# # PREPARE SUBMISSION

# %% [markdown]
# You will need to submit exact same file produced by using the following code. Any deviation from the desired format willbe marked as 0.

# %%
# Explain your approach

data_explanations = '''
\nThe dataframe contains 19 feautures. We trained our data with 11 features. We specifically not include text, description of tweet and user_id to training data.\nBasically the training data include numerical and categorical attributes, not verbal ones.
'''

feature_explanations = '''\nWe added some additional feautures for a better ML model. These feautures are user_verified and check. User_verified returns with a boolean value. States whether the user is verified by twitter or not.\nCheck is important for detecting political contents. If the tweets contains a word which determined in list_entities array and count them.\n
'''

model_explanations ='''
In the previous round we used randomforest classifier but in this round we used neural networks and find out results are much better compared to other models. We used 4 hidden layers with relu activation. In this model we need an optimizer so we choose Adam optimizer from keras library.Our results are continious values in the range of (0,1).
'''

additional_explanations = '''
Any other tricks that you tried for the project
'''

# %%
predictions = {
    'round': 2,
    'student_id': 28220,
    'user_predictions': modelPredUser,
    'tweet_predictions': modelPredTweet,
    'explanations': {
        'data': data_explanations,
        'feature': feature_explanations,
        'model': model_explanations,
        'other': additional_explanations,
    }
}


with open('predictions-{}_round{}.json'.format(STUDENT_ID, ROUND), 'w') as fl:
    fl.write(json.dumps(predictions, indent=4))

# %%
# Test your submission file

submission = json.load(open('predictions-{}_round{}.json'.format(STUDENT_ID, ROUND), 'r'))
submission
# Out:
# {'round': 2,
#  'student_id': 28220,
#  'user_predictions': {'nedenburdaysam': 0.33961252096982764,
#   'biologselim': 0.0720493923603477,
#   'bilgin21604923': 0.31444806639577605,
#   'denizlihabercom': 0.5378340997783233,
#   'burakerbaychp': 0.5071838126269395,
#   'mustafaarst': 0.45326639613860964,
#   'mvnez': 0.14058136797759574,
#   'farukhalit2': 0.478103299929,
#   'harlunoshi': 0.21222793301443166,
#   'tamerduran_1': 0.3066021582781926,
#   'donkisotumsu': 0.23678201773389487,
#   'enveraysevera': 0.478956191117688,
#   'gendenmukatol': 0.454695704195112,
#   '1905anason': 0.08575449648639255,
#   'dasiskein': 0.7188616264151886,
#   'ercan_bas29': 0.47342307912875853,
#   'mett_1907': 0.3861478575163155,
#   'haberinyokcokk': 0.05710981330487227,
#   'han34nesli': 0.33251247619157037,
#   'mehmetaltay64': 0.4423914700494359,
#   'nurtencam2': 0.3223372119027217,
#   'berkeduranovic': 0.32969575012718283,
#   'cagdasadim': 0.7159906637615387,
#   'yorumsuzadam87': 0.32682836405078336,
#   'twitsildiren': 0.6347560116568002,
#   'nurdiyoloji': 0.6818248461440982,
#   'merabalare': 0.4996329231383015,
#   'sevdaac72373936': 0.3488892804614941,
#   'cakan0_': 0.6215083695214767,
#   'ozlemesor': 0.33687303427578513,
#   'muratyazgan51': 0.6047639127078999,
#   'emre_caliskann': 0.5616171626321854,
#   'oguzhanonel': 0.5660662287547943,
#   'mintchocolatemx': 0.33627336965584337,
#   'mehmet07454846': 0.5511741449916491,
#   'lifegs': 0.15618612762780745,
#   'begumkarabeyx': 0.37189262497767395,
#   'mhakankocak': 0.34478944505998865,
#   'avutulan': 0.6481901257512312,
#   'imamgibiimam': 0.1528788041767857,
#   'durdane52': 0.4823936248147437,
#   'emsettinerdoan7': 0.5387220708205901,
#   'suaterce': 0.6195380184159922,
#   'ibrahimcalsskan': 0.7048112631611,
#   'uykusuz75': 0.3055831522241987,
#   'goksubayy': 0.4724810184798562,
#   'samobisus': 0.7239049922918636,
#   'haber': 0.6470966729968001,
#   'iddaaalkc': 0.0920319223727915,
#   'nnnccdd': 0.43878402644746595,
#   '_simurg1_': 0.5728675068471244,
#   'lasmananaskiss': 0.7326710361498626,
#   'kocakurt1806': 0.39853028641941035,
#   'anjelikaakbar': 0.6863654334489491,
#   'caglaademezler': 0.06820259367502891,
#   '_birgezgin_': 0.08097869410884569,
#   'alicemalakgl1': 0.11795913103969068,
#   'denizaydemirchp': 0.3221561048094896,
#   'delphinusdolfi': 0.4718145012618581,
#   'sevdesensoz': 0.19435981851663126,
#   'uortaogretim': 0.38857439370095176,
#   'furkanakinbjk': 0.8102984406294668,
#   'altinhakan': 0.5888500057237485,
#   'vedatkahyalar': 0.17916315000525096,
#   'jjuwark': 0.01856141623738145,
#   'chpfotograf': 0.8115964932003019,
#   'ibuzgan': 0.2450143309285914,
#   'emribilmaruf571': 0.29954863350129446,
#   'snurgo': 0.5927897280505393,
#   '1580929972650508289': 0.294685838118267,
#   '1416778304452009984': 0.4968591659781806,
#   '1352726914398613504': 0.12843978457409475,
#   '1433786614447329310': 0.5127945418048127,
#   '1595148835340226560': 0.5219119908708484,
#   '1366832249287622659': 0.1310079700839146,
#   '1583368510306103296': 0.4040518298627563,
#   '1592602720569286656': 0.5221227717282575,
#   '1352717957911220226': 0.3499677418359556,
#   '1594392174443237377': 0.3555303320606419,
#   '1429141139223941126': 0.45177815788913733,
#   '1579559691965038594': 0.5740532833528025,
#   '1347649378903875584': 0.1673402442809908,
#   '1593110096045019136': 0.5961946219893077,
#   '1595738052990828544': 0.35044653855704544,
#   '1570684907550121984': 0.5225413069151296,
#   '1596260609242595328': 0.5441805781934475,
#   '1588193781031047168': 0.5363358177568799,
#   '1588321676323950593': 0.5448528373064766,
#   '1577739161267847182': 0.56079900774945,
#   '1550545494962995200': 0.5687934131789134,
#   '1400907711148089348': 0.36005798424007873,
#   '1345052299870294017': 0.13038394205651715,
#   '1593638589199327232': 0.5230672165879154,
#   '1588592557436518400': 0.5465918130081903,
#   '1584983619466321920': 0.36344238230188014,
#   '1588102587466883072': 0.3612669812703234,
#   '1597579318141779974': 0.5410216228355502,
#   '1379837989904322563': 0.13138554625924803,
#   '1597472996725526528': 0.5240567567139718,
#   '1556024420640198656': 0.5758955645417467,
#   '1596923370062635008': 0.5819163374694004,
#   '1594360495137513474': 0.3265797090822312,
#   '1583483185102753792': 0.29079463113782916,
#   '1555072561377153027': 0.1314389896985648,
#   '1559264587115073539': 0.4926469452669151,
#   '1584969329439014913': 0.5409379561518817,
#   '1593734099755302915': 0.30463571688186275,
#   '1572285366354280448': 0.3999405270444526,
#   '1399798532069015563': 0.1295610879570981,
#   '1592569387965644813': 0.5226016693336123,
#   '1596564633573523457': 0.5231118410610778,
#   '1428460205688373262': 0.35320535329236596,
#   '1584995279870492672': 0.551136077463243,
#   '1357845356147523591': 0.1316439781177658,
#   '1583401145937993728': 0.5335972471307107,
#   '1395674766644846597': 0.12278082465538796,
#   '1594791011028729856': 0.5048154035274335,
#   '1453764017693110281': 0.13010621608234235,
#   '1563197082164678657': 0.5588620298638778,
#   '1387834568896569346': 0.36161701604134633,
#   '1593533012519653376': 0.29336048790253483,
#   '1347636415153246208': 0.3587328694209646,
#   '1593299475476381696': 0.2674355521681235,
#   '1596428480451055617': 0.5418818965902152,
#   ...},
#  'explanations': {'data': '\n\nThe dataframe contains 19 feautures. We trained our data with 11 features. We specifically not include text, description of tweet and user_id to training data.\nBasically the training data include numerical and categorical attributes, not verbal ones. \n',
#   'feature': '\nWe added some additional feautures for a better ML model. These feautures are user_verified and check. User_verified returns with a boolean value. States whether the user is verified by twitter or not.\nCheck is important for detecting political contents. If the tweets contains a word which determined in list_entities array and count them.\n\n',
#   'model': '\nIn the previous round we used randomforest classifier but in this round we used neural networks and find out results are much better compared to other models. We used 4 hidden layers with relu activation. In this model we need an optimizer so we choose Adam optimizer from keras library.Our results are continious values in the range of (0,1). \n',
#   'other': '\nAny other tricks that you tried for the project\n'}}
